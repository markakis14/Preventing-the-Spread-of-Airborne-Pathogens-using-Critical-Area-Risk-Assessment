# %%
import numpy as np
import imageio
# %matplotlib inline
import matplotlib.pyplot as plt
import math
import cv2
from random import seed
from random import randint
import networkx as nx
import timeit
from networkx.drawing.nx_pydot import write_dot
from scipy.spatial import distance
import csv
import random

numberOfDays=40 
walksPerDay=1
previousDay=0
dist=5
eucld=0
pfinal=0
seed()
relationshipFile = open("relationship.txt", "a")
relationshipFile2 = open("relationship2.txt", "a")
infoFile = open('info.txt','a')
resultlist = open("resultlist.txt", "a")
squaretext = open("squaretext.txt","a")
nodeList=[]
newInfected=[]
currentDay=[]
numberOfPeople=500 #original population is 2000
numberOfSteps=12000
stepsByHour=500
numberOfInfected=0
numberOfInfectious=1
numberOfSusceptible=499 # original number of suscetible is 1999

selectedObedient = random.sample(range(numberOfPeople),300)
#print("these are the selected", selectedObedient)
lista=[[[] for i in range(numberOfPeople)] for j in range(numberOfPeople)]
lista2=[[0,0] for i in range(numberOfPeople)]


people=dict(ID=['source','destination','state','virusLoad','virusLoadIncreaseRatio','pTalk','pCough','queue','roll','path','counterpath','flag','obedient','vector'])
states=['susceptible','infected','infectious','repaired']
hotspot=[250,210,180]
warmspot=[160,150,140,130]
coldspot=[60,50,40]
densityReductor=2
movingchance=math.floor((numberOfSteps-walksPerDay*150)/walksPerDay)
terminalCondition=0.99
contact_list_less_than_two=np.zeros(shape=numberOfPeople)
list1=[]
list2=[]
filenames=[]
filenames2=[]
contactQuarantineStep=11000
contactCheckDay=2
quarantineDuration=10
contactDuration=3
ResponseTime=2
contactDictionary={}
contactDictionary=dict()
vulnerability=[0,1,2,3,4,5]
pc=0.8
ps=0.5
pt=0.5
vc=2
vs=3
vt=0.5
vb=0.2
vlc=np.zeros(shape=(11,5))
vlc[0]=[0.8,0.1,0.05,0.05,0.1]
vlc[1]=[0.8,0.1,0.05,0.05,0.15]
vlc[2]=[0.8,0.1,0.05,0.05,0.2]
vlc[3]=[0.8,0.1,0.05,0.05,0.2]
vlc[4]=[0.8,0.1,0.05,0.05,0.2]
vlc[5]=[0.8,0.15,0.05,0.05,0.3]
vlc[6]=[0.8,0.20,0.05,0.05,0.4]
vlc[7]=[0.8,0.25,0.05,0.05,0.5]
vlc[8]=[0.8,0.30,0.05,0.05,0.6]
vlc[9]=[0.8,0.35,0.05,0.05,0.7]
vlc[10]=[0.8,0.40,0.05,0.05,0.8]
days_ContactDictionary=[]
chanceToMove={
    '0':2,
    '500':2,
    '1000':1,
    '1500':1,
    '2000':1,
    '2500':2,
    '3000':10,
    '3500':35,
    '4000':35,
    '4500':30,
    '5000':25,
    '5500':25,
    '6000':20,
    '6500':20,
    '7000':15,
    '7500':15,
    '8000':20,
    '8500':30,
    '9000':35,
    '9500':35,
    '10000':30,
    '10500':25,
    '11000':15,
    '11500':5
    
 
}

chanceToMoveMatrix=np.zeros(shape=12000)
for i in range(0,len(chanceToMoveMatrix)):
    if i<=500:
        chanceToMoveMatrix[i]=2
    elif i<=1000:
        chanceToMoveMatrix[i]=2
    elif i<=1500:
        chanceToMoveMatrix[i]=1
    elif i<=2000:
        chanceToMoveMatrix[i]=1
    elif i<=2500:
        chanceToMoveMatrix[i]=1
    elif i<=3000:
        chanceToMoveMatrix[i]=2
    elif i<=3500:
        chanceToMoveMatrix[i]=10
    elif i<=4000:
        chanceToMoveMatrix[i]=35
    elif i<=4500:
        chanceToMoveMatrix[i]=35
    elif i<=5000:
        chanceToMoveMatrix[i]=35
    elif i<=5500:
        chanceToMoveMatrix[i]=25
    elif i<=6000:
        chanceToMoveMatrix[i]=25
    elif i<=6500:
        chanceToMoveMatrix[i]=20
    elif i<=7000:
        chanceToMoveMatrix[i]=20
    elif i<=7500:
        chanceToMoveMatrix[i]=15
    elif i<=8000:
        chanceToMoveMatrix[i]=15
    elif i<=8500:
        chanceToMoveMatrix[i]=20
    elif i<=9000:
        chanceToMoveMatrix[i]=30
    elif i<=9500:
        chanceToMoveMatrix[i]=35
    elif i<=10000:
        chanceToMoveMatrix[i]=35
    elif i<=10500:
        chanceToMoveMatrix[i]=30
    elif i<=11000:
        chanceToMoveMatrix[i]=25
    elif i<=11500:
        chanceToMoveMatrix[i]=15
    else:
        chanceToMoveMatrix[i]=5
    

def attractionLeveling(attractionMap):
    hotDistance=5
    warmDistance=30
    flag=0
    for i in range(0,len(attractionMap)):
        for j in range(0,len(attractionMap[i])):
            if attractionMap[i][j]==100:
                flag=1
                attractionMap[i][j]=0
                attractionMap2[i][j]=0
                for k in range(1,warmDistance+1):
                        for l in range(1,warmDistance+1):
                            if(i+k<len(attractionMap)):
                                if(j+l<len(attractionMap[i])):
                                    if(k<hotDistance and l<hotDistance):
                                        value = randint(0, len(hotspot)-1)
                                        if attractionMap[k+i][j+l]==255:
                                            attractionMap[k+i][j+l]=hotspot[value]
                                            if value==0:
                                                attractionMap2[k+i][j+l]=10
                                            elif value==1:
                                                attractionMap2[k+i][j+l]=9
                                            else:
                                                attractionMap2[k+i][j+l]=8
                                        elif attractionMap[k+i][j+l]==0:
                                            pass
                                        elif attractionMap[k+i][j+l]==100:
                                            pass
                                        elif attractionMap[k+i][j+l]<hotspot[value] and attractionMap[k+i][j+l] not in hotspot:
                                            attractionMap[k+i][j+l]=hotspot[value]
                                            if value==0:
                                                attractionMap2[k+i][j+l]=10
                                            elif value==1:
                                                attractionMap2[k+i][j+l]=9
                                            else:
                                                attractionMap2[k+i][j+l]=8
                                    else:
                                        value = randint(0, len(warmspot)-1)
                                        if attractionMap[k+i][j+l]==255:
                                            attractionMap[k+i][j+l]=warmspot[value]
                                            if value==0:
                                                attractionMap2[k+i][j+l]=7
                                            elif value==1:
                                                attractionMap2[k+i][j+l]=6
                                            elif value==2:
                                                attractionMap2[k+i][j+l]=5
                                            elif value==3:
                                                attractionMap2[k+i][j+l]=4
                                        elif attractionMap[k+i][j+l]==0:
                                            pass
                                        elif attractionMap[k+i][j+l]==100:
                                            pass
                                        elif attractionMap[k+i][j+l]<warmspot[value] and (attractionMap[k+i][j+l] not in warmspot):
                                            attractionMap[k+i][j+l]=warmspot[value]
                                            if value==0:
                                                attractionMap2[k+i][j+l]=7
                                            elif value==1:
                                                attractionMap2[k+i][j+l]=6
                                            elif value==2:
                                                attractionMap2[k+i][j+l]=5
                                            elif value==3:
                                                attractionMap2[k+i][j+l]=4
                                if(j-l>0):
                                    if(k<hotDistance and l<hotDistance):
                                        value = randint(0, len(hotspot)-1)
                                        if attractionMap[k+i][j-l]==255:
                                            attractionMap[k+i][j-l]=hotspot[value]
                                            if value==0:
                                                attractionMap2[k+i][j-l]=10
                                            elif value==1:
                                                attractionMap2[k+i][j-l]=9
                                            else:
                                                attractionMap2[k+i][j-l]=8
                                        elif attractionMap[k+i][j-l]==0:
                                            pass
                                        elif attractionMap[k+i][j-l]==100:
                                            pass
                                        elif attractionMap[k+i][j-l]<hotspot[value] and (attractionMap[k+i][j-l] not in hotspot):
                                            attractionMap[k+i][j-l]=hotspot[value]
                                            if value==0:
                                                attractionMap2[k+i][j-l]=10
                                            elif value==1:
                                                attractionMap2[k+i][j-l]=9
                                            else:
                                                attractionMap2[k+i][j-l]=8
                                    else:
                                        value = randint(0, len(warmspot)-1)
                                        if attractionMap[k+i][j-l]==255:
                                            attractionMap[k+i][j-l]=warmspot[value]
                                            if value==0:
                                                attractionMap2[k+i][j-l]=7
                                            elif value==1:
                                                attractionMap2[k+i][j-l]=6
                                            elif value==2:
                                                attractionMap2[k+i][j-l]=5
                                            elif value==3:
                                                attractionMap2[k+i][j-l]=4
                                        elif attractionMap[k+i][j-l]==0:
                                            pass
                                        elif attractionMap[k+i][j-l]==100:
                                            pass
                                        elif attractionMap[k+i][j-l]<warmspot[value] and(attractionMap[k+i][j-l] not in warmspot):
                                            attractionMap[k+i][j-l]=warmspot[value]
                                            if value==0:
                                                attractionMap2[k+i][j-l]=7
                                            elif value==1:
                                                attractionMap2[k+i][j-l]=6
                                            elif value==2:
                                                attractionMap2[k+i][j-l]=5
                                            elif value==3:
                                                attractionMap2[k+i][j-l]=4
                            if(i-k>0):
                                if(j+l<len(attractionMap[i])):
                                    if(k<hotDistance and l<hotDistance):
                                        value = randint(0, len(hotspot)-1)
                                        if attractionMap[i-k][j+l]==255:
                                            attractionMap[i-k][j+l]=hotspot[value]
                                            if value==0:
                                                attractionMap2[i-k][j+l]=10
                                            elif value==1:
                                                attractionMap2[i-k][j+l]=9
                                            else:
                                                attractionMap2[i-k][j+l]=8                                           
                                        elif attractionMap[i-k][j+l]==0:
                                            pass
                                        elif attractionMap[i-k][j+l]==100:
                                            pass
                                        elif attractionMap[i-k][j+l]<hotspot[value] and(attractionMap[i-k][j+l] not in hotspot):
                                            attractionMap[i-k][j+l]=hotspot[value]
                                            if value==0:
                                                attractionMap2[i-k][j+l]=10
                                            elif value==1:
                                                attractionMap2[i-k][j+l]=9
                                            else:
                                                attractionMap2[i-k][j+l]=8           
                                    else:
                                        value = randint(0, len(warmspot)-1)
                                        if attractionMap[i-k][j+l]==255:
                                            attractionMap[i-k][j+l]=warmspot[value]
                                            if value==0:
                                                attractionMap2[i-k][j+l]=7
                                            elif value==1:
                                                attractionMap2[i-k][j+l]=6
                                            elif value==2:
                                                attractionMap2[i-k][j+l]=5
                                            elif value==3:
                                                attractionMap2[i-k][j+l]=4
                                        elif attractionMap[i-k][j+l]==0:
                                            pass
                                        elif attractionMap[i-k][j+l]==100:
                                            pass
                                        elif attractionMap[i-k][j+l]<warmspot[value] and (attractionMap[i-k][j+l] not in warmspot):
                                            attractionMap[i-k][j+l]=warmspot[value]
                                            if value==0:
                                                attractionMap2[i-k][j+l]=7
                                            elif value==1:
                                                attractionMap2[i-k][j+l]=6
                                            elif value==2:
                                                attractionMap2[i-k][j+l]=5
                                            elif value==3:
                                                attractionMap2[i-k][j+l]=4
                                if(j-l>0):
                                    if(k<hotDistance and l<hotDistance):
                                        value = randint(0, len(hotspot)-1)
                                        if attractionMap[i-k][j-l]==255:
                                            attractionMap[i-k][j-l]=hotspot[value]
                                            if value==0:
                                                attractionMap2[i-k][j-l]=10
                                            elif value==1:
                                                attractionMap2[i-k][j-l]=9
                                            else:
                                                attractionMap2[i-k][j-l]=8           
                                        elif attractionMap[i-k][j-l]==0:
                                            pass
                                        elif attractionMap[i-k][j-l]==100:
                                            pass
                                        elif attractionMap[i-k][j-l]<hotspot[value] and(attractionMap[i-k][j-l] not in hotspot):
                                            attractionMap[i-k][j-l]=hotspot[value]
                                            if value==0:
                                                attractionMap2[i-k][j-l]=10
                                            elif value==1:
                                                attractionMap2[i-k][j-l]=9
                                            else:
                                                attractionMap2[i-k][j-l]=8           
                                    else:
                                        value = randint(0, len(warmspot)-1)
                                        if attractionMap[i-k][j-l]==255:
                                            attractionMap[i-k][j-l]=warmspot[value]
                                            if value==0:
                                                attractionMap2[i-k][j-l]=7
                                            elif value==1:
                                                attractionMap2[i-k][j-l]=6
                                            elif value==2:
                                                attractionMap2[i-k][j-l]=5
                                            elif value==3:
                                                attractionMap2[i-k][j-l]=4
                                        elif attractionMap[i-k][j-l]==0:
                                            pass
                                        elif attractionMap[i-k][j-l]==100:
                                            pass
                                        elif attractionMap[i-k][j-l]<warmspot[value] and (attractionMap[i-k][j-l] not in warmspot):
                                            attractionMap[i-k][j-l]=warmspot[value]
                                            if value==0:
                                                attractionMap2[i-k][j-l]=7
                                            elif value==1:
                                                attractionMap2[i-k][j-l]=6
                                            elif value==2:
                                                attractionMap2[i-k][j-l]=5
                                            elif value==3:
                                                attractionMap2[i-k][j-l]=4
    for i in range(0,len(attractionMap)):
        if flag==0:
                break
        for j in range(0,len(attractionMap[i])):
            if attractionMap[i][j]==255:
                value = randint(0, len(coldspot)-1)
                attractionMap[i][j]=coldspot[value]
                if value==0:
                    attractionMap2[i][j]=1                    
                elif value==1:
                    attractionMap2[i][j]=2        
                elif value==2:
                    attractionMap2[i][j]=3
            elif attractionMap[i][j]==100:
                attractionMap[i][j]=0
                attractionMap2[i][j]=0
    return attractionMap

def attractionMapping(Mmap):
    attractionMap=np.array(Mmap);
    for i in range(0,len(Mmap)):
        for j in range(0,len(Mmap[i])):
            if (Mmap[i][j]!=0 and Mmap[i][j]!=255):
                attractionMap[i][j]=100
    attractionMap2=attractionMap
    attractionMap=attractionLeveling(attractionMap)
    return attractionMap

def coloring(backtorgb):
    for i in range(0,len(backtorgb)):
        for j in range(0,len(backtorgb[i])):
            if(attractionMap2[i][j]==10):
                backtorgb[i][j][2]=139
                backtorgb[i][j][0]=0
                backtorgb[i][j][1]=0
            elif(attractionMap2[i][j]==9):
                backtorgb[i][j][2]=255
                backtorgb[i][j][0]=0
                backtorgb[i][j][1]=0
            elif(attractionMap2[i][j]==8):
                backtorgb[i][j][2]=255
                backtorgb[i][j][0]=0
                backtorgb[i][j][1]=140
            elif(attractionMap2[i][j]==7):
                backtorgb[i][j][2]=255
                backtorgb[i][j][0]=0
                backtorgb[i][j][1]=165
            elif(attractionMap2[i][j]==6):
                backtorgb[i][j][2]=230
                backtorgb[i][j][0]=0
                backtorgb[i][j][1]=80
            elif(attractionMap2[i][j]==5):
                backtorgb[i][j][2]=255
                backtorgb[i][j][0]=0
                backtorgb[i][j][1]=255
            elif(attractionMap2[i][j]==4):
                backtorgb[i][j][2]=144
                backtorgb[i][j][0]=144
                backtorgb[i][j][1]=238
            elif(attractionMap2[i][j]==3):
                backtorgb[i][j][2]=0
                backtorgb[i][j][0]=255
                backtorgb[i][j][1]=255
            elif(attractionMap2[i][j]==2):
                backtorgb[i][j][2]=255
                backtorgb[i][j][0]=255
                backtorgb[i][j][1]=0
            elif(attractionMap2[i][j]==1):
                backtorgb[i][j][2]=0
                backtorgb[i][j][0]=255
                backtorgb[i][j][1]=0
            else:
                backtorgb[i][j][2]=0
                backtorgb[i][j][0]=0
                backtorgb[i][j][1]=0       
    cv2.imwrite('output.png', backtorgb)
    #cv2.imwrite('output2.png', attractionMap)\n",
    stop = timeit.default_timer()
    print('Time: ', stop - start)

def createGraph(Gmap):
    for i in range (0,len(idMap)):
        for j in range(0,len(idMap[i])):
            if idMap[i][j]!=0:
                Gmap.add_node(str(i)+','+str(j))
                Gmap.nodes[str(i)+','+str(j)]['coordinates']=[i,j]
    #initializing weights\n",
    for i in range (0,len(idMap)):
        for j in range(0,len(idMap[i])):
            if (j+1<len(idMap[i])) and idMap[i][j]!=0 and idMap[i][j+1]!=0: 
                Gmap.add_edge(str(i)+','+str(j),str(i)+','+str(j+1),distanc=10-attractionMap2[i][j] + 10-attractionMap2[i][j+1] + 1)
                #print(Gmap.edges[str(i)+','+str(j), str(i)+','+str(j+1)][weight])
            if (i+1<len(idMap) and (j-1>=0) and idMap[i+1][j-1]!=0 and idMap[i][j]!=0 ):
                Gmap.add_edge(str(i)+','+str(j),str(i+1)+','+str(j-1),distanc=10-attractionMap2[i][j] + 10-attractionMap2[i+1][j-1] + 1)
            if (i+1<len(idMap) and idMap[i+1][j]!=0 and idMap[i][j]!=0):
                Gmap.add_edge(str(i)+','+str(j),str(i+1)+','+str(j),distanc=10-attractionMap2[i][j] + 10-attractionMap2[i+1][j] + 1)
            if (i+1<len(idMap) and (j+1<len(idMap[i])) and (idMap[i+1][j+1]!=0) and (idMap[i][j]!=0)):
                Gmap.add_edge(str(i)+','+str(j),str(i+1)+','+str(j+1),distance=10-attractionMap2[i][j] + 10-attractionMap2[i+1][j+1] + 1)      
    
    print('number of nodes =',Gmap.number_of_nodes())
    print('number of edges =',Gmap.number_of_edges())
    #nx.drawing.nx_pylab.draw_networkx_nodes(Gmap,pos=nx.spring_layout(Gmap))
    
    for node in Gmap.nodes:
        nodeList.append(node)
        #if Gmap.degree(node)==8:\n",
            #print(node)\n",
            #print([Gmap.adj[node].keys()])\n",
            #for i in Gmap.adj[node]:\n",
                #print(i)\n",
                #3print(Gmap.nodes[i])\n",
            #3break\n",
    return Gmap

def createPeople():
    start = timeit.default_timer()
    for i in range(0,numberOfPeople):
        if i<numberOfSusceptible:
            tmp=[]
            x=[]
            y=[]
            sourceRng=-1
            destinationRng=-1
            state=states[0]
            virusLoad=0
            virusIncreaseLoad=0
            pTalk=randint(1,100)
            pCough=randint(1,100)
            queue=[]
            roll=0
            path=[]
            counterpath=0
            flag=0
            viralLoadMatrix=[]
            lastnode=0
            doi=-1
            startDateSymptom=randint(3,6)
            fiftyToHundrend=randint(3,5)
            currentDateOfCurve=-1
            viralLoadMatrix.append(0)
            countdown=0
            home=-1
            squaretext=[]
            stepToMove=-1
            daysAfterSymptoms=0
            quarantineFlag=0
            passedDayOfSymptom=0
            
            
            for j in range(1,(startDateSymptom)):
                viralLoadMatrix.append(randint(1,49))
            viralLoadMatrix.sort()
            viralLoadMatrix.append(50)
            startToBeInfectious=(len(viralLoadMatrix)-2)
            for j in range(0,fiftyToHundrend-1):
                viralLoadMatrix.append(randint(51,99))
            viralLoadMatrix.sort()
            for j in viralLoadMatrix:
                tmp.append(j)
            tmp.reverse()
            viralLoadMatrix.append(100)
            for j in tmp:
                viralLoadMatrix.append(j)
            duration=len(viralLoadMatrix)       
            people[i]=[sourceRng,destinationRng,state,virusLoad,virusIncreaseLoad,pTalk,pCough,queue,roll,path,counterpath,flag,viralLoadMatrix,doi,startDateSymptom,fiftyToHundrend,duration,currentDateOfCurve,startToBeInfectious,lastnode,home,countdown,stepToMove,squaretext,daysAfterSymptoms,quarantineFlag,passedDayOfSymptom,1 if(i in selectedObedient) else 0,[0,0,0,0]]
            for j in range(0,len(viralLoadMatrix)):    
                x.append(j)
                y.append(viralLoadMatrix[j])

        else:
            tmp=[]
            x=[]
            y=[]
            sourceRng=-1
            destinationRng=-1
            state=states[2]
            virusLoad=0
            virusIncreaseLoad=0
            pTalk=randint(1,100)
            pCough=randint(1,100)
            queue=[]
            roll=0
            path=[]
            counterpath=0
            flag=0
            viralLoadMatrix=[]
            doi=0
            startDateSymptom=randint(3,6)
            fiftyToHundrend=randint(3,5)
            currentDateOfCurve=0
            lastnode=0
            viralLoadMatrix.append(0)
            countdown=0
            home=-1
            squaretext=[]
            stepToMove=-1
            daysAfterSymptoms=0
            quarantineFlag=0
            passedDayOfSymptom=0

            
            if i!=numberOfPeople-1:
                for j in range(1,(startDateSymptom)):
                    viralLoadMatrix.append(randint(1,49))
                viralLoadMatrix.sort()
                viralLoadMatrix.append(50)
                startToBeInfectious=(len(viralLoadMatrix)-2)
                for j in range(0,fiftyToHundrend-1):
                    viralLoadMatrix.append(randint(51,99))
                viralLoadMatrix.sort()
                for j in viralLoadMatrix:
                    tmp.append(j)
                tmp.reverse()
                viralLoadMatrix.append(100)
                for j in tmp:
                    viralLoadMatrix.append(j)
                duration=len(viralLoadMatrix)      
                people[i]=[sourceRng,destinationRng,state,virusLoad,virusIncreaseLoad,pTalk,pCough,queue,roll,path,counterpath,flag,viralLoadMatrix,doi,startDateSymptom,fiftyToHundrend,duration,currentDateOfCurve,startToBeInfectious,lastnode,home,countdown,stepToMove,squaretext,daysAfterSymptoms,quarantineFlag,passedDayOfSymptom,1 if(i in selectedObedient) else 0,[0,0,0,0]]
                for j in range(0,len(viralLoadMatrix)):
                    x.append(j)
                    y.append(viralLoadMatrix[j])
            elif i==numberOfPeople-1:
                startDateSymptom=5
                startvalue=10
                for j in range(0,20):
                    if startvalue>100:
                        startvalue=100
                    if j>=10:
                        if j==11:
                            startvalue=startvalue
                        startvalue=startvalue-10
                        viralLoadMatrix.append(startvalue)
                    else:            
                        viralLoadMatrix.append(startvalue)
                        startvalue=startvalue+10
                people[i]=[sourceRng,destinationRng,state,virusLoad,virusIncreaseLoad,pTalk,pCough,queue,roll,path,counterpath,flag,viralLoadMatrix,doi,startDateSymptom,fiftyToHundrend,duration,currentDateOfCurve,startToBeInfectious,lastnode,home,countdown,stepToMove,squaretext,daysAfterSymptoms,quarantineFlag,passedDayOfSymptom,1 if(i in selectedObedient) else 0,[0,0,0,0]]
                for j in range(0,len(viralLoadMatrix)):
                    x.append(j)
                    y.append(viralLoadMatrix[j])
                    
                plt.bar(10,viralLoadMatrix[startDateSymptom+fiftyToHundrend+2] , color="red",width=0.1, bottom=None,)
                plt.bar(startDateSymptom,viralLoadMatrix[startDateSymptom] , color="orange",width=0.1, bottom=None,)
                plt.bar(len(viralLoadMatrix)-startDateSymptom-1,viralLoadMatrix[len(viralLoadMatrix)-startDateSymptom-1] , color="orange",width=0.1, bottom=None,)
                plt.plot(x,y, color='black', linewidth=3)
                plt.xticks(range(1,25))
                plt.yticks(range(0,100,10))
                plt.show()
    return people
    end = timeit.default_timer()
    print('Time: ', end - start)
    start = timeit.default_timer()
    
def createRealationshipGraph(people):
    dice=0
    for i in range(0,len(people)):
        Grelationship.add_node(i)
    for i in range(0,len(people)):
        for j in range(0,len(people)):
            if i!=j:
                dice=randint(0,2)
                if dice==1:
                    Grelationship.add_edge(i,j)
    for i in range(0,len(people)):
        relationshipFile.write(str(i))
        for j in Grelationship.neighbors(i):
            relationshipFile.write(',')
            relationshipFile.write(str(j))
        relationshipFile.write('\n')
    return Grelationship

  
def checkIfInfect(s,eucld,l):
    if s==l:
        return 0
    if people[s][2]=='infectious':
        #print(s)
        #print(l)
        if(people[s][17]>=len(people[s][12])):
            people[s][17]=0
            people[s][2]='immune'
            return 0
        flr=math.floor(people[s][12][people[s][17]])/10
        pb=randint(0,vlc[int(flr)][0]*1000)
        pc=randint(0,vlc[int(flr)][1]*1000)
        ps=randint(0,vlc[int(flr)][2]*1000)
        pt=randint(0,vlc[int(flr)][3]*1000)
        if pb>pc and pb>ps and pb>pt:
            pfinal=vlc[int(math.floor(people[s][12][people[s][17]]/10))][4]*vb/(1+(eucld*eucld))

        elif pc>pb and pc>ps and pc>pt:
            pfinal=vlc[int(math.floor(people[s][12][people[s][17]]/10))][4]*vc/(1+(eucld*eucld))

        elif ps>pb and ps>pc and ps>pt:
            pfinal=vlc[int(math.floor(people[s][12][people[s][17]]/10))][4]*vs/(1+(eucld*eucld))

        else:
            pfinal=vlc[int(math.floor(people[s][12][people[s][17]]/10))][4]*vt/(1+(eucld*eucld))

        dice=randint(0,1000)
        #print('dice=',dice)
        #print('pfinal=,',pfinal*1000)
        if pfinal*1000>dice and people[l][2]=='susceptible':
            return 1
        else:
            return 0
    else:
        return 0
    
def checkNewDestination(people,j): #### synartisi metaforas A->B
    backOrNew=randint(0,5)
    people[j][21]=randint(0,10)
    if backOrNew==1: 
        people[j][1]=nodeList[randint(0,len(nodeList)-1)]
        if people[j][19]!=0:
                people[j][0]=people[j][19]
        else:
                people[j][0]=nodeList[randint(0,len(nodeList)-1)]
                people[j][20]=people[j][0]
        src=people[j][0]
        dest=people[j][1]
        people[j][19]=dest
        people[j][11]=1
        people[j][10]=0
        people[j][9]=(nx.dijkstra_path(Gmap,people[j][0],people[j][1],weight='distanc'))
    else:
        people[j][0]=people[j][19]
        people[j][1]=people[j][20]
        people[j][10]=0       
        people[j][11]=1
        people[j][9]=(nx.dijkstra_path(Gmap,people[j][0],people[j][1],weight='distanc'))
    return people
    
def checkGraphDensity(people,step):
    insideGraph=0
    for i in range(0,len(people)-1):
        if (people[i][0]!=-1 and people[i][1]!=-1):
            insideGraph=insideGraph+1
    if insideGraph/numberOfPeople<=chanceToMoveMatrix[step]/(100*densityReductor):
        return 0
    else:
        return 1
    
def checkGraphDensity2(people,step):
    insideGraph=0
    for i in range(0,len(people)-1):
        if (people[i][0]!=-1 and people[i][1]!=-1):
            insideGraph=insideGraph+1
    print(insideGraph/numberOfPeople,step)

    
def putQuarantine(peopleID):
    people[peopleID][0]=-1
    people[peopleID][1]=-1
    people[peopleID][25]=1
    people[peopleID][10]=0
    people[peopleID][11]=0
    people[peopleID][9]=[]
    return people
    
def quarantineContacts(peopleID,o,contactDictionary):
    daysBefore=2
    contactDuration=3
    #print(contactDictionary)
    #print(contactDictionary[peopleID])
    for i in contactDictionary[peopleID]:
        if i[1]>3:
            putQuarantine(i[0])
    for i in range(o-daysBefore,o):
        for cont in days_ContactDictionary[i][peopleID]:
            #print(cont)
            if cont[1]>3:
                #print([cont[0]])
                #print(days_ContactDictionary[i][peopleID])
                putQuarantine(cont[0])
    return people
############################################################################################################
def checkContact(id1,status1,id2,status2,eucld,step,vector): #check contact def 

    lista[id1][id2].append([status1,status2,eucld,step])
    if(len(lista[id1][id2])>=5): # if the lenght >=5 then the sim steps are >=5  
        if(status1=="infected" or status1=="infectious"):   #vector=[1,0,0,0] or [0,1,0,0]
            people[id1][28]=getStatus(id1,id2,status1,status2,vector)
        #afairw prwti eggrafi k krataw tin 6 gia na anaewsw tiw 5 teleytaies epafes wste na einai contact kapoios.
        #sthn elif elegxw to teleytaio step - to prvto step an einai consecutive and h synoliki apostasi sta 5 steps na einai <=2 ==> an isxyei einai epafi
        elif((lista[id1][id2][4][3]-lista[id1][id2][0][3]==4) and (lista[id1][id2][0][2] + lista[id1][id2][1][2] + lista[id1][id2][2][2] + lista[id1][id2][3][2] + lista[id1][id2][4][2])/5<=2):    
            if(status2 == "infected" or status2=="infectious"):   #vector=[0,0,1,0]
                people[id1][28]=getStatus(id1,id2,status1,status2,vector)
                #print("ok2")
            if(people[id2][28]==[0,0,1,0]): #vector=[0,0,0,1]
                people[id1][28]=getStatus(id1,id2,status1,"Coinfected",vector)
                #print("ok3")
        del lista[id1][id2][0]


def getStatus(id1,id2,status1,status2,status_vector):
    if status1 == "infectious":
        status_vector = [1,0,0,0]
        #print(status_vector)
    elif status1 == "infected" and status_vector[0]!=1: #people[l][2]
        status_vector = [0,1,0,0]
        #print(status_vector)
    elif (status2=="infected" or status2=="infectious") and status_vector[0]!=1 and status_vector[1]!=1: #oles tis epafes twn infected 
        status_vector = [0,0,1,0]
        #print(status_vector)
    elif status2=="Coinfected" and status_vector==[0,0,0,0]: # oles tis epafes twn epafwn twn infected
        status_vector = [0,0,0,1]
        #print(status_vector)

    return status_vector
    

def calcAreaRisk2(lista2):
    ArForStep=[0 for i in range(numberOfPeople)]
    WA=0.7
    WB=0.2
    WC=0.09

    for i in range(numberOfPeople):
        x, y = lista2[i][0], lista2[i][1]
        x_min = x-5
        x_max = x+5
        y_min = y-5
        y_max = y+5
        infectiousCount = 0
        infectedCount = 0
        contactsOfInfectedCount = 0 #contacts of infected
        contactsOfContactsOfInfectedCount = 0 #contacts of contacts of infected

        for j in range(numberOfPeople):
            if i != j:
                xj, yj = lista2[j][0], lista2[j][1]
                if x_min <= xj <= x_max and y_min <= yj <= y_max:
                    v=people[j][28]
                    infectiousCount += v[0]
                    infectedCount += v[1]
                    contactsOfInfectedCount += v[2]
                    contactsOfContactsOfInfectedCount += v[3]

        numerator = (WA *(infectiousCount + infectedCount) + WB * contactsOfInfectedCount + WC * contactsOfContactsOfInfectedCount)
        denominator = WA*(infectiousCount + infectedCount + contactsOfInfectedCount + contactsOfContactsOfInfectedCount)
        
        if denominator == 0:
            ArForStep[i] = 0
        else:
            ArForStep[i] = numerator*(1.0) / denominator*(1.0)
            #print(ArForStep)
    return ArForStep


def outcome(ArForStep):
    with open('obedient300stous500v1.csv', mode='w', newline='') as file: 
        writer = csv.writer(file)
        writer.writerow(["Day", "Num of Infections"])
        for day, num_inf in zip(currentDay, newInfected):
            writer.writerow([day, num_inf])

        for i in range(numberOfPeople):
            if people[i][27] ==1 and ArForStep[i]> 0.6 : 
                checkNewDestination(people, i)
                #print("i told him to leave", i)

    return ArForStep
                        
        

    
def simulate():
    global lista2
    checkIfTimeForDice=1
    fr=0
    infectedOverall=0
    outputimage=np.zeros((len(Mmap),len(Mmap[0]),3))
    outputimage2=np.zeros((len(Mmap),len(Mmap[0]),3))
    basicFrame=np.zeros((len(Mmap),len(Mmap[0]),3))
    frequencyOfWalks=0
    colorRoads=[]
    infectedPerDay=1
    previousDay=0
    dice=0
    count=0
    nodeToColorx=[]
    nodeToColory=[]
    numOfInfected=0
    contact={}
    for o in range(0,numberOfDays):
        checkIfTimeForDice=1
        previousDay=previousDay+infectedPerDay
        numOfInfected=0
        if o>0:
            days_ContactDictionary.append(contactDictionary)
            for i in range(0,len(Mmap)):
                for j in range(0,len(Mmap[0])):
                    Mmap[i][j][0]=Mmap[i][j][1]
                    outputimage2[i][j][0]=Mmap[i][j][0]
                    outputimage2[i][j][1]=Mmap[i][j][1]
                    outputimage2[i][j][2]=Mmap[i][j][2]
                    outputimage[i][j][0]=basicFrame[i][j][0]
                    outputimage[i][j][1]=basicFrame[i][j][1]
                    outputimage[i][j][2]=basicFrame[i][j][2]                      
            for i in range(0,len(Mmap)):
                for j in range(0,len(Mmap[0])):
                    Mmap[i][j][0]=Mmap[i][j][1]
                    if Mmap3[i][j][2]==255 and Mmap3[i][j][1]==0 and  Mmap3[i][j][0]==0:
                        outputimage[i][j][0]=0
                        outputimage[i][j][1]=0
                        outputimage[i][j][2]=255
                    elif Mmap3[i][j][1]==255  and Mmap3[i][j][0]==0 and Mmap3[i][j][2]==0:
                        outputimage[i][j][0]=0
                        outputimage[i][j][1]=255
                        outputimage[i][j][2]=0
                    if Mmap4[i][j][0]==255:
                        outputimage2[i][j][0]=255
                        outputimage2[i][j][1]=0
                        outputimage2[i][j][2]=255


            cv2.imwrite('peoplemove'+str(o)+'.png', outputimage)
            cv2.imwrite('peoplemove_2.png', Mmap)
            #cv2.imwrite('combined'+str(o)+'.png', outputimage)
            cv2.imwrite('krousmata'+str(o)+'.png', outputimage2)
            filenames.append('peoplemove'+str(o)+'.png')
            filenames2.append('krousmata'+str(o)+'.png')
            
            for i in range(0,len(Mmap)):
                for j in range(0,len(Mmap[0])):
                    #if outputimage[i][j][0]!=255 and outputimage[i][j][1]!=0 and outputimage[i][j][2]!=255:
                    Mmap3[i][j]=Mmap[i][j]                      
                    outputimage[i][j]=Mmap[i][j]
            for y in range(0,numberOfPeople):
                if (people[y][2]=='infectious'):
                    people[y][17]=people[y][17]+1
                elif (people[y][2]=='infected'):
                    people[y][2]='infectious'
                    
        if o==0:
            for i in range(0,len(Mmap)):
                for j in range(0,len(Mmap[0])):
                    if Mmap[i][j][0]>200:
                        Mmap[i][j][0]=25
                        Mmap[i][j][1]=25
                        Mmap[i][j][2]=25
                        Mmap3[i][j][0]=25
                        Mmap3[i][j][1]=25
                        Mmap3[i][j][2]=25
                        Mmap4[i][j][0]=25
                        Mmap4[i][j][1]=25
                        Mmap4[i][j][2]=25
                        basicFrame[i][j][0]=25
                        basicFrame[i][j][1]=25
                        basicFrame[i][j][2]=25
            cv2.imwrite('peoplemove.png', Mmap)
            #cv2.imwrite('peoplemove_2.png', Mmap)
            #cv2.imwrite('combined'+str(o)+'.png', outputimage)
            cv2.imwrite('krousmata'+str(o)+'.png', Mmap)
            #for i in range(0,len(Mmap)):
                #for j in range(0,len(Mmap[0])):
                    #Mmap[i][j][0]=0
                    
        for step in range(0,numberOfSteps):

            updateTable=[]
            if step == contactQuarantineStep:
                for j in range(0,numberOfPeople):
                    if people[j][24]==ResponseTime:
                        putQuarantine(j)
                        quarantineContacts(j,o,contactDictionary)
            if step ==0:
                contactDictionary={}
                #contactDictionary=dict()
                for i in range(0,numberOfPeople):
                    contactDictionary.update({i:[[-1,-1]]})
                    if(people[i][17]>=len(people[i][12])):
                        people[i][17]=0
                        people[i][2]='immune'
                    if len(people[i][12])>people[i][17]:
                        if (people[i][2]=='infectious' and people[i][12][people[i][17]]>=50) or people[i][26]==1:
                            people[i][24]=people[i][24]+1
                            people[i][26]=1
                    if people[i][24]==quarantineDuration + ResponseTime:
                        people[i][25]=0
                        if people[i][2]=='susceptible':
                            people[i][2]='susceptible'
                        else:
                            people[i][2]='immune'
                    #print(contactDictionary)
            if str(step) in chanceToMove:
                print(step)
                checkGraphDensity2(people,step)
                sus=0
                inf=0
                infe=0
                im=0
                numOfQuarantined=0
                for i in range(0,numberOfPeople):
                    if people[i][25]==1:
                        numOfQuarantined+=1
                    if people[i][2]=='susceptible':
                        sus=sus+1
                    elif people[i][2]=='infected':
                        inf=inf+1
                    elif people[i][2]=='infectious':
                        infe=infe+1
                    elif people[i][2]=='immune':
                        im=im+1
                print("susceptible=",sus," infected=",inf," infectious=",infe,"immune",im,"quarantined",numOfQuarantined)
                infoFile.write(str(sus)+','+str(inf)+","+str(infe)+','+str(im))
                infoFile.write('\n')
                if inf==0 and infe==0:
                    return 0
                            
            #print(people[0][0])
            #print(people[0][1])
            #print(people[0][20])
            if step==numberOfSteps-1:
                cnt=0
                numOfInfected=0
                #########################################
                for y in range(0,numberOfPeople):
                    if (people[y][2]=='infectious'):
                        cnt=cnt+1
                    if (people[y][2]=='infected'):
                        numOfInfected=numOfInfected+1
                #######################################
                #if step==numberOfSteps-1:
                infectedPerDay=numOfInfected
                if cnt>=numberOfPeople*terminalCondition:
                    print('pandemic!!!!')
                    print('numOfInfected',numOfInfected)
                    print('day',o)
                    print('step',step)
                    return 1
                list1.append(o+1)
                list2.append(infectedOverall)
                resultlist.write('number of infectious in step '+str( step)+'='+str( cnt)+' day='+str( o)+' hour='+str(float((step/12000))))
                resultlist.write("\n")
                resultlist.write('number of infected in step '+str( step)+'='+str( numOfInfected)+' day='+str( o)+' hour='+str(float((step/1200))))
                resultlist.write("\n")
                #print('number of infectius in step',step,'=',cnt,'day=',o,'hour=',float((step/1000)*24))
                #print(people[0])\n",
            contact={}
            for j in range(0,numberOfPeople):
                if people[j][25]==0:
                    #check if goes back or chose other destination
                    if people[j][0]==people[j][1] and people[j][1]!=-1 and people[j][20]!=people[j][0]:
                        checkNewDestination(people,j)
                    if ((str(int(step))in chanceToMove) and ((people[j][0]==people[j][1] and people[j][20]==people[j][0]) or (people[j][0]==people[j][1] and people[j][1]==-1))):
                        people[j][10]=0
                        people[j][9]=[]
                        people[j][0]=-1
                        people[j][1]=-1
                        people[j][8]=randint(0,100)
                        people[j][11]=0
                        if people[j][8]<= chanceToMove[str(int(step))]:
                            #print('step',step)
                            #print(j)   
                            people[j][22]=randint(step,step+500)
                    if people[j][22]==step:
                        if checkGraphDensity(people,step)==0:
                            people[j][22]=-1
                            people[j][1]=nodeList[randint(0,len(nodeList)-1)]
                            if people[j][19]!=0:
                                people[j][0]=people[j][19]
                            else:
                                people[j][0]=nodeList[randint(0,len(nodeList)-1)]
                                if people[j][20]==-1:
                                    people[j][20]=people[j][0]
                            src=people[j][0]
                            dest=people[j][1]
                            people[j][19]=dest
                            people[j][11]=1
                            people[j][9]=(nx.dijkstra_path(Gmap,people[j][0],people[j][1],weight='distanc'))
                            #people[j][19]=people[j][9][len(people[j][9])-1]
                            #print((nx.dijkstra_path(Gmap,people[j][0],people[j][1],weight='weight')))
                            #print(nx.dijkstra_path(Gmap,people[j][0],people[j][1]))
                            #print((nx.dijkstra_path(Gmap,people[j][0],people[j][1],weight='weight')))
                            colorRoads=[]
                            for node in people[j][9]:
                                colorRoads.append(node.split(','))
                            #print(colorRoads)
                            for i in range(0,len(colorRoads)):

                                if Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][0]<255 and Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][1]<255 and Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][2]<255:
                                    Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][0]=1+Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][0]
                                    Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][1]=1+Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][1]
                                    Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][2]=1+Mmap[int(colorRoads[i][0])][int(colorRoads[i][1])][2]
                                if i==len(colorRoads)-1:
                                    if people[j][2]=="susceptible":
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][0]=0
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][1]=255
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][2]=0

                                        if(int(colorRoads[i][0])+1)<len(Mmap3):
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])][0]=0
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])][1]=255
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])][2]=0                                        

                                        if(int(colorRoads[i][0])-1)>0:
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])][0]=0
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])][1]=255
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])][2]=0                                        

                                        if(int(colorRoads[i][1])+1)<len(Mmap3[0]):
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])+1][0]=0
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])+1][1]=255
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])+1][2]=0

                                        if(int(colorRoads[i][1])-1)>0:
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])-1][0]=0
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])-1][1]=255
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])-1][2]=0
                                    elif people[j][2]=='infectious':                                    
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][0]=0
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][1]=0
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][2]=255

                                        if(int(colorRoads[i][0])+1)<len(Mmap3) and (int(colorRoads[i][1])+1)<len(Mmap3[0]):
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])+1][0]=0
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])+1][1]=0
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])+1][2]=255

                                        if(int(colorRoads[i][0])-1)>0 and (int(colorRoads[i][1])-1)>0:
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])-1][0]=0
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])-1][1]=0
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])-1][2]=255

                                        if(int(colorRoads[i][0])-1)>0 and (int(colorRoads[i][1])+1)<len(Mmap3[0]):
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])+1][0]=0
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])+1][1]=0
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])+1][2]=255

                                        if(int(colorRoads[i][0])+1)<len(Mmap3) and (int(colorRoads[i][1])+1)>0:
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])-1][0]=0
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])-1][1]=0
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])-1][2]=255

                                elif i==0:
                                    if people[j][2]=="susceptible":
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][0]=25
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][1]=25
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][2]=25

                                        if int(colorRoads[i][0])+1<len(Mmap3):
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])][0]=25
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])][1]=25
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])][2]=25

                                        if int(colorRoads[i][0])-1>0:
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])][0]=25
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])][1]=25
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])][2]=25

                                        if int(colorRoads[i][1])+1<len(Mmap3[0]):
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])+1][0]=25
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])+1][1]=25
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])+1][2]=25

                                        if int(colorRoads[i][1])-1>0:
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])-1][0]=25
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])-1][1]=25
                                            Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])-1][2]=25
                                    elif people[j][2]=='infectious':
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][0]=25
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][1]=25
                                        Mmap3[int(colorRoads[i][0])][int(colorRoads[i][1])][2]=25

                                        if int(colorRoads[i][0])+1<len(Mmap3) and  int(colorRoads[i][1])+1<len(Mmap3[0]):
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])+1][0]=25
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])+1][1]=25
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])+1][2]=25


                                        if int(colorRoads[i][0])-1>0 and int(colorRoads[i][1])-1>0:
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])-1][0]=25
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])-1][1]=25
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])-1][2]=25

                                        if int(colorRoads[i][0])-1>0 and  int(colorRoads[i][1])+1<len(Mmap3[0]):
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])+1][0]=25
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])+1][1]=25
                                            Mmap3[int(colorRoads[i][0])-1][int(colorRoads[i][1])+1][2]=25

                                        if int(colorRoads[i][0])+1<len(Mmap3) and int(colorRoads[i][1])-1>0:
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])-1][0]=25
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])-1][1]=25
                                            Mmap3[int(colorRoads[i][0])+1][int(colorRoads[i][1])-1][2]=25




                            frequencyOfWalks+=1
                        else:
                            people[j][22]=-1
                    if people[j][11]==1:
                        if people[j][10]<len(people[j][9]) and people[j][21]==0:
                            people[j][0]=people[j][9][people[j][10]]
                            people[j][10]=people[j][10]+1
                            if people[j][0] not in contact:
                                contact[people[j][0]]=[j]
                            #elif people[j][0]>0:
                                #contact[people[j][0]].append(j)
                        elif people[j][21]>0:
                            people[j][21]=people[j][21]-1
                        else:
                            #people[j][19]=people[j][1]
                            people[j][9]=[]
                            people[j][10]=0
                            people[j][11]=0
                            #people[j][0]=-1
                            #people[j][0]=-people[j][0]
                            #people[j][1]=-1
                            people[j][21]=0
                            if people[j][0] not in contact:
                                contact[people[j][0]]=[j]

                                            
            for k in contact:
                seperator2=[]
                seperator2=k.split(',')
                checkIfMoreThanTwo=0
                for l in contact[k]:
                    #checking for possible new relations
                    if len(contact[k])>1:
                        for m in contact[k]:
                            if m!=l and l in Grelationship.neighbors(m) and people[l][21]==0:
                                people[m][21]=randint(0,10)
                                people[l][21]=randint(0,10)
                                checkIfMoreThanTwo=checkIfMoreThanTwo+1
                        for m in contact[k]:
                            chanceForNewEdge=0
                            if checkIfMoreThanTwo>2:
                                print("more than two")
                                if m!=l and l not in Grelationship.neighbors(m):
                                    print("not relation")
                                    chanceForNewEdge=randint(0,2)
                                    if chanceForNewEdge==1:
                                        print("new edge!")
                                        Grelationship.add_edge(l,m)   
                                    
                    flag=0
                    if len(people[l][9])-2>people[l][10]:
                        seperator1=[]
                        seperator1=people[l][9][people[l][10]+1].split(',')
                        currentstepx=int(seperator2[0])
                        currentstepy=int(seperator2[1])          
                        nextstepx=int(seperator1[0])
                        nextstepy=int(seperator1[1])
                    elif len(people[l][9])-2==people[l][10]:
                        seperator1=[]
                        seperator1=people[l][9][people[l][10]].split(',')
                        currentstepx=int(seperator2[0])
                        currentstepy=int(seperator2[1])          
                        nextstepx=int(seperator1[0])
                        nextstepy=int(seperator1[1])
                    else:
                        flag=1
                    if flag==0:
                            #checkingsquare neighboors
                            #inside
                        if currentstepx>=0 and currentstepy>=0:
                            flagg2=0
                            if(attractionMap[currentstepx][currentstepy]!=0):
                                if(str(currentstepx)+','+str(currentstepy) in contact):
                                    for s in contact[str(currentstepx)+','+str(currentstepy)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break
                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx)+','+str(currentstepy)),people[s][2],step])
                                 #up
                        if currentstepx-1>0:
                            flagg2=0
                            if(attractionMap[currentstepx-1][currentstepy]!=0):
                                if(str(currentstepx-1)+','+str(currentstepy) in contact):
                                    for s in contact[str(currentstepx-1)+','+str(currentstepy)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break
                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx-1)+','+str(currentstepy)),people[s][2],step])

                            #upnright
                        if currentstepx-1>0 and currentstepy+1<len(attractionMap[0]):
                            flagg2=0
                            if(attractionMap[currentstepx-1][currentstepy+1]!=0):
                                if(str(currentstepx-1)+','+str(currentstepy+1) in contact):
                                    for s in contact[str(currentstepx-1)+','+str(currentstepy+1)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break

                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx-1)+','+str(currentstepy+1)),people[s][2],step])
                            #right
                        if currentstepy+1<len(attractionMap[0]):
                            if(attractionMap[currentstepx][currentstepy+1]!=0):
                                if(str(currentstepx)+','+str(currentstepy+1) in contact):
                                    for s in contact[str(currentstepx)+','+str(currentstepy+1)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break

                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx)+','+str(currentstepy+1)),people[s][2],step])
                            #rightndown
                        if currentstepx+1<len(attractionMap) and currentstepy+1<len(attractionMap[0]):
                            if(attractionMap[currentstepx+1][currentstepy+1]!=0):
                                if(str(currentstepx+1)+','+str(currentstepy+1) in contact):
                                    for s in contact[str(currentstepx+1)+','+str(currentstepy+1)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')                                            
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break

                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx+1)+','+str(currentstepy+1)),people[s][2],step])
                            #down
                        if currentstepx+1<len(attractionMap):
                            if(attractionMap[currentstepx+1][currentstepy]!=0):
                                if(str(currentstepx+1)+','+str(currentstepy) in contact):
                                    for s in contact[str(currentstepx+1)+','+str(currentstepy)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break
                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx+1)+','+str(currentstepy)),people[s][2],step])
                            #downnleft
                        if currentstepx+1<len(attractionMap) and currentstepy-1>0:
                            if(attractionMap[currentstepx+1][currentstepy-1]!=0):
                                if(str(currentstepx+1)+','+str(currentstepy-1) in contact):
                                    for s in contact[str(currentstepx+1)+','+str(currentstepy-1)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break
                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx+1)+','+str(currentstepy-1)),people[s][2],step])
                            #left
                        if currentstepy-1>0:
                            if(attractionMap[currentstepx][currentstepy-1]!=0):
                                if(str(currentstepx)+','+str(currentstepy-1) in contact):
                                    for s in contact[str(currentstepx)+','+str(currentstepy-1)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break
                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx)+','+str(currentstepy-1)),people[s][2],step])
                            #leftnup
                        if currentstepx-1>0 and currentstepy-1>0:
                            if(attractionMap[currentstepx-1][currentstepy-1]!=0):
                                if(str(currentstepx-1)+','+str(currentstepy-1) in contact):
                                    for s in contact[str(currentstepx-1)+','+str(currentstepy-1)]:
                                        if s!=l:
                                            flagg2=0
                                            seperator1=[]
                                            seperator2=[]
                                            seperator1=people[l][0].split(',')
                                            seperator2=people[s][0].split(',')
                                            for citizen in contactDictionary[l]:
                                                if s in citizen:
                                                    flagg2=1
                                                    break
                                            if flagg2==0:
                                                if s<l:
                                                    if [s,l] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([s,l])
                                                elif l<s:
                                                    if [l,s] not in updateTable:
                                                        contactDictionary[l].append([s,1])
                                                        contactDictionary[s].append([l,1])
                                                        updateTable.append([l,s])
                                            else:
                                                for k in contactDictionary[l]:
                                                    if k[0]==s:
                                                        k[1]=k[1]+1
                                                        break
                                                for k in contactDictionary[s]:
                                                    if k[0]==l:
                                                        k[1]=k[1]+1
                                                        break
                                            people[l][23].append([l,people[l][0],people[l][2],s,(str(currentstepx-1)+','+str(currentstepy-1)),people[s][2],step])
                        
                        if nextstepx>currentstepx and nextstepy>currentstepy:
                            counter=-1
                            for m in range(currentstepx,currentstepx+dist+1):
                                counter=counter+1
                                for n in range(currentstepy,currentstepy+dist+1-counter):
                                    if m<len(attractionMap) and n<len(attractionMap[0]):
                                        if(attractionMap[m][n]!=0):
                                            if(str(m)+','+str(n) in contact):
                                                for s in contact[str(m)+','+str(n)]:
                                                    if s!=l:
                                                        seperator1=[]
                                                        seperator2=[]
                                                        seperator1=people[l][0].split(',')
                                                        seperator2=people[s][0].split(',')
                                                        eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
                                                        if eucld<=2 and l in Grelationship[s]:
                                                            people[s][21]=randint(0,10)
                                                            people[l][21]=people[s][21]
                                                            #print(l)
                                                            #print(s)
                                                        if checkIfInfect(s,eucld,l)==1:
                                                            people[l][13]=o
                                                            infectedOverall+=1
                                                            people[l][2]="infected"
                                                            people[l][17]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][1]=0 
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][1]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][1]=0 
                                                            #cv2.imwrite('peoplemove.png', Mmap)       
                                                            #cv2.imwrite('peoplemove.png', Mmap)       
                                                        people[l][7].append([l,people[l][0],people[l][2],s,(str(m)+','+str(n)),people[s][2],eucld,step,people[l][27]])
                                                        checkContact(l,people[l][2],s,people[s][2],eucld,step,people[l][28])
                                                        lista2[l]=[m,n]
                                                        #print(lista2[l])
                        #lower
                        elif nextstepx>currentstepx and nextstepy==currentstepy:
                            counter=-1
                            for m in range(currentstepx,currentstepx+dist+1):
                                counter=counter+1
                                for n in range(currentstepy-counter,currentstepy+counter+1):
                                    if m<len(attractionMap) and n<len(attractionMap[0]):
                                        if(attractionMap[m][n]!=0):
                                            if(str(m)+','+str(n) in contact):
                                                for s in contact[str(m)+','+str(n)]:
                                                    if s!=l:
                                                        seperator1=[]
                                                        seperator2=[]
                                                        seperator1=people[l][0].split(',')
                                                        seperator2=people[s][0].split(',')
                                                        eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
                                                        if eucld<=2 and l in Grelationship[s]:
                                                            people[s][21]=randint(0,10)
                                                            people[l][21]=people[s][21]
                                                            #print(l)
                                                            #print(s) 
                                                        if checkIfInfect(s,eucld,l)==1:
                                                            people[l][2]="infected"
                                                            people[l][13]=o
                                                            infectedOverall+=1
                                                            people[l][17]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][1]=0 
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][1]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][1]=0 
                                                            #cv2.imwrite('peoplemove.png', Mmap)       
                                                        people[l][7].append([l,people[l][0],people[l][2],s,(str(m)+','+str(n)),people[s][2],eucld,step,people[l][27]])
                                                        checkContact(l,people[l][2],s,people[s][2],eucld,step,people[l][28])
                                                        lista2[l]=[m,n]
                        #lowerLeft
                        elif nextstepx>currentstepx and nextstepy<currentstepy:
                            counter=-1
                            for m in range(currentstepx,currentstepx+dist+1):
                                counter=counter+1
                                for n in range(currentstepy,currentstepy-dist-1+counter,-1):
                                    if m<len(attractionMap) and n<len(attractionMap[0]):
                                        if(attractionMap[m][n]!=0):
                                            if(str(m)+','+str(n) in contact):
                                                for s in contact[str(m)+','+str(n)]:
                                                    if s!=l:
                                                        seperator1=[]
                                                        seperator2=[]
                                                        seperator1=people[l][0].split(',')
                                                        seperator2=people[s][0].split(',')
                                                        eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
                                                        if eucld<=2 and l in Grelationship[s]:
                                                            people[s][21]=randint(0,10)
                                                            people[l][21]=people[s][21]
                                                            #print(l)
                                                            #print(s)
                                                        if checkIfInfect(s,eucld,l)==1:
                                                            infectedOverall+=1
                                                            people[l][13]=o
                                                            people[l][2]="infected"
                                                            people[l][17]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][1]=0 
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][1]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][1]=0 
                                                            #cv2.imwrite('peoplemove.png', Mmap)       
                                                        people[l][7].append([l,people[l][0],people[l][2],s,(str(m)+','+str(n)),people[s][2],eucld,step,people[l][27]])
                                                        checkContact(l,people[l][2],s,people[s][2],eucld,step,people[l][28])
                                                        lista2[l]=[m,n]
                                                        #print(lista2[l])
                        #left
                        elif nextstepx==currentstepx and nextstepy<currentstepy:
                            counter=-1
                            for n in range(currentstepy,currentstepy-dist-1,-1):
                                counter=counter+1
                                for m in range(currentstepx-counter,currentstepx+counter+1):
                                    if m<len(attractionMap) and n<len(attractionMap[0]):
                                        if(attractionMap[m][n]!=0):
                                            if(str(m)+','+str(n) in contact):
                                                for s in contact[str(m)+','+str(n)]:
                                                    if s!=l:
                                                        seperator1=[]
                                                        seperator2=[]
                                                        seperator1=people[l][0].split(',')
                                                        seperator2=people[s][0].split(',')
                                                        eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
                                                        if eucld<=2 and l in Grelationship[s]:
                                                            people[s][21]=randint(0,10)
                                                            people[l][21]=people[s][21]
                                                            #print(l)
                                                            #print(s)
                                                        if checkIfInfect(s,eucld,l)==1:
                                                            infectedOverall+=1
                                                            people[l][2]="infected"
                                                            people[l][13]=o
                                                            people[l][17]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][1]=0 
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][1]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][1]=0 
                                                            #cv2.imwrite('peoplemove.png', Mmap)       
                                                        people[l][7].append([l,people[l][0],people[l][2],s,(str(m)+','+str(n)),people[s][2],eucld,step,people[l][27]])            
                                                        checkContact(l,people[l][2],s,people[s][2],eucld,step,people[l][28])
                                                        lista2[l]=[m,n]
                                                        
                        #upperLeft
                        elif nextstepx>currentstepx and nextstepy<currentstepy:
                            counter=-1
                            for m in range(currentstepx,currentstepx-dist-1,-1):
                                counter=counter+1
                                for n in range(currentstepy,currentstepy-dist-1-counter,-1):
                                    if m<len(attractionMap) and n<len(attractionMap[0]):
                                        if(attractionMap[m][n]!=0):
                                            if(str(m)+','+str(n) in contact):
                                                for s in contact[str(m)+','+str(n)]:
                                                    if s!=l:
                                                        seperator1=[]
                                                        seperator2=[]
                                                        seperator1=people[l][0].split(',')
                                                        seperator2=people[s][0].split(',')
                                                        eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
                                                        if eucld<=2 and l in Grelationship[s]:
                                                            people[s][21]=randint(0,10)
                                                            people[l][21]=people[s][21]
                                                            #print(l)
                                                            #print(s) 
                                                        if checkIfInfect(s,eucld,l)==1:
                                                            infectedOverall+=1
                                                            people[l][2]="infected"
                                                            people[l][13]=o
                                                            people[l][17]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][1]=0 
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][1]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][1]=0 
                                                            #cv2.imwrite('peoplemove.png', Mmap)       
                                                        people[l][7].append([l,people[l][0],people[l][2],s,(str(m)+','+str(n)),people[s][2],eucld,step,people[l][27]])
                                                        checkContact(l,people[l][2],s,people[s][2],eucld,step,people[l][28])
                                                        lista2[l]=[m,n]
                                                       
                        #upper
                        elif nextstepx<currentstepx and nextstepy==currentstepy:
                            counter=-1
                            for m in range(currentstepx,currentstepx-dist-1,-1):
                                counter=counter+1
                                for n in range(currentstepy-counter,currentstepy+counter+1):
                                    if m<len(attractionMap) and n<len(attractionMap[0]):
                                        if(attractionMap[m][n]!=0):
                                            if(str(m)+','+str(n) in contact):
                                                for s in contact[str(m)+','+str(n)]:
                                                    if s!=l:
                                                        seperator1=[]
                                                        seperator2=[]
                                                        seperator1=people[l][0].split(',')
                                                        seperator2=people[s][0].split(',')
                                                        eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
                                                        if eucld<=2 and l in Grelationship[s]:
                                                            people[s][21]=randint(0,10)
                                                            people[l][21]=people[s][21]
                                                            #print(l)
                                                            #print(s)
                                                        if checkIfInfect(s,eucld,l)==1:
                                                            people[l][13]=o
                                                            infectedOverall+=1
                                                            people[l][2]="infected"
                                                            people[l][17]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][1]=0 
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][1]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][1]=0 
                                                            #cv2.imwrite('peoplemove.png', Mmap)
                                                        people[l][7].append([l,people[l][0],people[l][2],s,(str(m)+','+str(n)),people[s][2],eucld,step,people[l][27]])      
                                                        checkContact(l,people[l][2],s,people[s][2],eucld,step,people[l][28])
                                                        lista2[l]=[m,n]
                                                        
                        #upperRight
                        elif nextstepx>currentstepx and nextstepy<currentstepy:
                            counter=-1
                            for m in range(currentstepx,currentstepx-dist-1,-1):
                                counter=counter+1
                                for n in range(currentstepy,currentstepy+dist+1+counter):
                                        if(attractionMap[m][n]!=0):
                                            if(str(m)+','+str(n) in contact):
                                                for s in contact[str(m)+','+str(n)]:
                                                    if s!=l:
                                                        seperator1=[]
                                                        seperator2=[]
                                                        seperator1=people[l][0].split(',')
                                                        seperator2=people[s][0].split(',')
                                                        eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
                                                        if eucld<=2 and l in Grelationship[s]:
                                                            people[s][21]=randint(0,10)
                                                            people[l][21]=people[s][21]
                                                            #print(l)
                                                            #print(s)
                                                        if checkIfInfect(s,eucld,l)==1:
                                                            infectedOverall+=1
                                                            people[l][2]="infected"
                                                            people[l][13]=o
                                                            people[l][17]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][1]=0 
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][1]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][1]=0 
                                                            #cv2.imwrite('peoplemove.png', Mmap)
                                                        people[l][7].append([l,people[l][0],people[l][2],s,(str(m)+','+str(n)),people[s][2],eucld,step,people[l][27]])      
                                                        checkContact(l,people[l][2],s,people[s][2],eucld,step,people[l][28])
                                                        lista2[l]=[m,n]
                                                        
                    
                        #Right
                        elif nextstepx==currentstepx and nextstepy>currentstepy:
                            counter=-1 
                            for n in range(currentstepy,currentstepy+(dist+1)):
                                counter=counter+1
                                for m in range(currentstepx-counter,currentstepx+counter+1):
                                    if m<len(attractionMap) and n<len(attractionMap[0]):
                                        if(attractionMap[m][n]!=0):
                                            if(str(m)+','+str(n) in contact):
                                                for s in contact[str(m)+','+str(n)]:
                                                    if s!=l:
                                                        seperator1=[]
                                                        seperator2=[]
                                                        seperator1=people[l][0].split(',')
                                                        seperator2=people[s][0].split(',')
                                                        eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
                                                        if eucld<=2 and l in Grelationship[s]:
                                                            people[s][21]=randint(0,10)
                                                            people[l][21]=people[s][21]
                                                            #print(l)
                                                            #print(s) 
                                                        if checkIfInfect(s,eucld,l)==1:
                                                            infectedOverall+=1
                                                            people[l][2]="infected"
                                                            people[l][13]=o
                                                            people[l][17]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])+1][int(seperator1[1])][1]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][2]=0
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][0]=255
                                                            Mmap4[int(seperator1[0])-1][int(seperator1[1])][1]=0 
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])+1][1]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][2]=0
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][0]=255
                                                            Mmap4[int(seperator1[0])][int(seperator1[1])-1][1]=0 
                                                            #cv2.imwrite('peoplemove.png', Mmap)
                                                        people[l][7].append([l,people[l][0],people[l][2],s,(str(m)+','+str(n)),people[s][2],eucld,step,people[l][27]])    
                                                        checkContact(l,people[l][2],s,people[s][2],eucld,step,people[l][28])
                                                        lista2[l]=[m,n]
                                                        
                #################################################
#                tmp=[]
#                tmp=k.split(',')
#                x=int(tmp[0])
#                y=int(tmp[1])
#                for i in range(x-dist,x+dist):
#                    if i>=0 and i<len(attractionMap):
#                        for j in range(y-dist,y+dist):
#                            if i!=x and j!=y:
#                                if j>=0 and j<len(attractionMap[0]):
#                                    if(attractionMap[i][j]!=0):
#                                        if(str(i)+','+str(j) in contact):
#                                            for l in contact[k]:
#                                                for m in contact[str(i)+','+str(j)]:
#                                                    seperator1=people[l][0].split(',')
#                                                    seperator2=people[m][0].split(',')
#                                                    eucld=distance.euclidean((float(seperator1[0]),float(seperator1[1])),(float(seperator2[0]),float(seperator2[1])))
#                                                    if people[m][2]=='infectius':
#                                                        flr=math.floor(people[m][12][people[m][17]])/10
#                                                        pb=randint(0,vlc[int(flr)][0]*1000)
#                                                        pc=randint(0,vlc[int(flr)][1]*1000)
#                                                        ps=randint(0,vlc[int(flr)][2]*1000)
#                                                        pt=randint(0,vlc[int(flr)][3]*1000)
#                                                        if pb>pc and pb>ps and pb>pt:
#                                                            pfinal=vlc[int(math.floor(people[m][12][people[m][17]]/10))][4]*vb/(eucld*eucld)
                                                            #print("pb",vlc[int(math.floor(people[m][12][people[m][17]]/10))][0])
                                                            #print("vlc",vlc[int(math.floor(people[m][12][people[m][17]]/10))][4])
                                                            #print("vb",vb)
                                                            #print("eucld",eucld)
#                                                        elif pc>pb and pc>ps and pc>pt:
#                                                            pfinal=vlc[int(math.floor(people[m][12][people[m][17]]/10))][4]*vc/(eucld*eucld)
#                                                            print("pc",vlc[int(math.floor(people[m][12][people[m][17]]/10))][1])
#                                                          print("vlc",vlc[int(math.floor(people[m][12][people[m][17]]/10))][4])
#                                                           print('vc',vc)
#                                                            print('eucld',eucld)
#                                                        elif ps>pb and ps>pc and ps>pt:
#                                                            pfinal=vlc[int(math.floor(people[m][12][people[m][17]]/10))][4]*vs/(eucld*eucld)
#                                                            print("ps",vlc[int(math.floor(people[m][12][people[m][17]]/10))][2])
#                                                            print("vlc",vlc[int(math.floor(people[m][12][people[m][17]]/10))][4])
#                                                            print("vs",vs)
#                                                            print("eucld",eucld)
#                                                        else:
#                                                            pfinal=vlc[int(math.floor(people[m][12][people[m][17]]/10))][4]*vt/(eucld*eucld)
                                                            #print("pt",vlc[int(math.floor(people[m][12][people[m][17]]/10))][3])
                                                            #print("vlc",vlc[int(math.floor(people[m][12][people[m][17]]/10))][4])
                                                            #print("vt",vt)
                                                            #print('eucld',eucld)
#                                                        dice=randint(0,1000)
#                                                        print(dice)
#                                                        print(pfinal*1000)
#                                                        if pfinal*1000>dice and people[l][2]!='infectius':
#                                                            people[l][2]="infectius"
#                                                            people[l][17]=0
#                                                            Mmap[int(seperator1[0])][int(seperator1[1])][2]=255
#                                                            Mmap[int(seperator1[0])][int(seperator1[1])][0]=0
#                                                            Mmap[int(seperator1[0])][int(seperator1[1])][1]=0
#                                                            cv2.imwrite('peoplemove.png', Mmap)
#                                                            
#                                                    people[l][7].append([l,people[l][0],people[l][2],m,(str(i)+','+str(j)),people[m][2],eucld,step])
            #if step==11999:
                #days_ContactDictionary.append(contactDictionary)
        outcome(calcAreaRisk2(lista2))
        newInfected.append(infectedPerDay)
        currentDay.append(o+1)
        print('new', infectedPerDay,'infected people ')
        for h in range(0,len(people)-1):
            if people[h][25]==0:
                fr=fr+1
        print("fr",fr)
        if fr>0:
            print('frequencyOfWalks',frequencyOfWalks/fr)
        frequencyOfWalks=0
        fr=0
        
                                                    
                                                    
                                                    
                                            
                                                    #print(people[l][7])

                                    
                                    #for contacts in contact[neighboor2]:\n",
                                     #   if(people[contacts][2]=='infectius'):\n",
                                      #      for contacts2 in contact[neighboor2]:\n",
                                       #         infect.append([contacts2,people[contacts2][0]])\n",
                                        #    break                  \n",
            #for p in range(0,len(infect)):\n",
              #  people[infect[p][0]][2]='infectius'\n",
            #print(people[infect[p]][0])\n",
        #print(infect)\n",
        #print(\"-----------------------\")\n",
    
    

# initializing Mmap(black and white google map image) and idMap\n",
img = cv2.imread('im2.png', 0)
Mmap=np.array(img)
Mmap3=np.array(img)
Mmap4=np.array(img)
idMap = np.zeros((len(Mmap),len(Mmap[0])))
idCounter=1
contactlist = open("contactlist.txt", "a")
for i in range (0,len(Mmap)):
    for j in range(0,len(Mmap[i])):
        if Mmap[i][j]>=100:
            Mmap[i][j]=255
            Mmap3[i][j]=255
            Mmap4[i][j]=255
            idMap[i][j]=idCounter
            idCounter=idCounter+1
        else:
            Mmap[i][j] = 0
            Mmap3[i][j] = 0
            idMap[i][j] = 0
            Mmap4[i][j] = 0
cv2.imwrite('fillAttractionImage2.png', Mmap)
cv2.imwrite('peoplemove.png', Mmap)
ready = input("Please enter a number when attraction points are ready")
start = timeit.default_timer()
attractionMap2 = np.zeros((len(Mmap),len(Mmap[0])))
attractionImage = cv2.imread('fillAttractionImage2.png', 0)
Mmap2 = np.array(attractionImage)
#creating attractionMap\n",
attractionMap = attractionMapping(Mmap2);
backtorgb = cv2.cvtColor(attractionMap,cv2.COLOR_GRAY2RGB)
Mmap = cv2.cvtColor(Mmap,cv2.COLOR_GRAY2RGB)
Mmap3 = cv2.cvtColor(Mmap3,cv2.COLOR_GRAY2RGB)
Mmap4 = cv2.cvtColor(Mmap4,cv2.COLOR_GRAY2RGB)
coloring(backtorgb)
#creating Graph Gmap\n",
Gmap = nx.Graph()
Grelationship = nx.Graph()
Gmap=createGraph(Gmap)
#creating people\n",
people=createPeople()
Grelationship=createRealationshipGraph(people)
#for j in range(0,300):\n",
#    print(people[j][2])\n",
start = timeit.default_timer()
simulate()
end = timeit.default_timer()
print('Time: ', end - start)
plt.xticks(np.arange(min(list1), max(list1)+1, 1.0))
plt.plot(list1,list2, color='blue', linewidth=3)
plt.show()
            
#for i in people[60][7]:
#    print(i)
#print(people[931][7])

for i in range(0,(len(people)-1)):
    contactlist.write(str(people[i][7]))
    contactlist.write('\n')
    contactlist.write("\n")
    contactlist.write("\n")
    squaretext.write(str(people[i][23]))
    squaretext.write("\n")
    squaretext.write("\n")
    squaretext.write("\n")
#for i in people[727][7]:
#    print(i)


#finding Gmap Diameter\n",
#test=nx.dijkstra_path(Gmap,1,Gmap.number_of_nodes(),weight='weight')\n",
#print(len(test))"
# Out:
# Please enter a number when attraction points are ready10
# Time:  325.34322690000045
# number of nodes = 7267
# number of edges = 23227
# 0
# 0.0 0
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 500
# 0.012 500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 1000
# 0.012 1000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 1500
# 0.006 1500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 2000
# 0.006 2000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 2500
# 0.006 2500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 3000
# 0.012 3000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 3500
# 0.052 3500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 4000
# 0.176 4000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 4500
# 0.176 4500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 5000
# 0.176 5000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 5500
# 0.126 5500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 6000
# 0.126 6000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 6500
# 0.102 6500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 7000
# 0.102 7000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 7500
# 0.076 7500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 8000
# 0.076 8000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 8500
# 0.102 8500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 9000
# 0.152 9000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 9500
# 0.176 9500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 10000
# 0.176 10000
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 10500
# 0.152 10500
# susceptible= 499  infected= 0  infectious= 1 immune 0 quarantined 0
# 11000
# 0.126 11000
# susceptible= 498  infected= 1  infectious= 1 immune 0 quarantined 0
# 11500
# 0.076 11500
# susceptible= 498  infected= 1  infectious= 1 immune 0 quarantined 0
# i told him to leave 87
# i told him to leave 169
# i told him to leave 179
# i told him to leave 251
# new 1 infected people
# fr 500
# frequencyOfWalks 2.05
# 0
# 0.034 0
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 500
# 0.012 500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 1000
# 0.012 1000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 1500
# 0.006 1500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 2000
# 0.006 2000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 2500
# 0.006 2500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 3000
# 0.012 3000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 3500
# 0.052 3500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 4000
# 0.176 4000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 4500
# 0.176 4500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 5000
# 0.176 5000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 5500
# 0.126 5500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 6000
# 0.126 6000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 6500
# 0.102 6500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 7000
# 0.102 7000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 7500
# 0.076 7500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 8000
# 0.076 8000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 8500
# 0.102 8500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 9000
# 0.152 9000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 9500
# 0.176 9500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 10000
# 0.176 10000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 10500
# 0.152 10500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 11000
# 0.126 11000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 11500
# 0.076 11500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# i told him to leave 36
# i told him to leave 80
# i told him to leave 87
# i told him to leave 162
# i told him to leave 167
# i told him to leave 260
# i told him to leave 294
# i told him to leave 316
# i told him to leave 361
# i told him to leave 439
# new 0 infected people
# fr 500
# frequencyOfWalks 2.036
# 0
# 0.044 0
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 500
# 0.02 500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 1000
# 0.012 1000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 1500
# 0.006 1500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 2000
# 0.006 2000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 2500
# 0.006 2500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 3000
# 0.012 3000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 3500
# 0.052 3500
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 4000
# 0.176 4000
# susceptible= 498  infected= 0  infectious= 2 immune 0 quarantined 0
# 4500
# 0.176 4500
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 5000
# 0.176 5000
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 5500
# 0.126 5500
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 6000
# 0.126 6000
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 6500
# 0.102 6500
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 7000
# 0.102 7000
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 7500
# 0.076 7500
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 8000
# 0.076 8000
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 8500
# 0.102 8500
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 9000
# 0.152 9000
# susceptible= 497  infected= 1  infectious= 2 immune 0 quarantined 0
# 9500
# 0.176 9500
# susceptible= 496  infected= 2  infectious= 2 immune 0 quarantined 0
# 10000
# 0.176 10000
# susceptible= 496  infected= 2  infectious= 2 immune 0 quarantined 0
# 10500
# 0.152 10500
# susceptible= 496  infected= 2  infectious= 2 immune 0 quarantined 0
# 11000
# 0.126 11000
# susceptible= 496  infected= 2  infectious= 2 immune 0 quarantined 0
# 11500
# 0.076 11500
# susceptible= 496  infected= 2  infectious= 2 immune 0 quarantined 0
# i told him to leave 96
# i told him to leave 296
# i told him to leave 298
# i told him to leave 313
# i told him to leave 314
# i told him to leave 450
# i told him to leave 477
# i told him to leave 491
# new 2 infected people
# fr 500
# frequencyOfWalks 2.054
# 0
# 0.042 0
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 500
# 0.016 500
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 1000
# 0.012 1000
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 1500
# 0.006 1500
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 2000
# 0.006 2000
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 2500
# 0.006 2500
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 3000
# 0.012 3000
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 3500
# 0.052 3500
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 4000
# 0.176 4000
# susceptible= 496  infected= 0  infectious= 4 immune 0 quarantined 0
# 4500
# 0.176 4500
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 5000
# 0.176 5000
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 5500
# 0.126 5500
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 6000
# 0.126 6000
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 6500
# 0.102 6500
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 7000
# 0.102 7000
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 7500
# 0.076 7500
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 8000
# 0.076 8000
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 8500
# 0.102 8500
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 9000
# 0.152 9000
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 9500
# 0.176 9500
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 10000
# 0.176 10000
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 10500
# 0.152 10500
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 11000
# 0.126 11000
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# 11500
# 0.076 11500
# susceptible= 495  infected= 1  infectious= 4 immune 0 quarantined 0
# i told him to leave 8
# i told him to leave 64
# i told him to leave 79
# i told him to leave 103
# i told him to leave 132
# i told him to leave 152
# i told him to leave 162
# i told him to leave 163
# i told him to leave 187
# i told him to leave 223
# i told him to leave 227
# i told him to leave 270
# i told him to leave 292
# i told him to leave 297
# i told him to leave 322
# i told him to leave 339
# i told him to leave 340
# i told him to leave 344
# i told him to leave 370
# i told him to leave 372
# i told him to leave 426
# i told him to leave 445
# i told him to leave 447
# i told him to leave 494
# new 1 infected people
# fr 500
# frequencyOfWalks 2.068
# 0
# 0.074 0
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 500
# 0.048 500
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 1000
# 0.012 1000
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 1500
# 0.006 1500
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 2000
# 0.006 2000
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 2500
# 0.006 2500
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 3000
# 0.012 3000
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 3500
# 0.052 3500
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 4000
# 0.176 4000
# susceptible= 495  infected= 0  infectious= 5 immune 0 quarantined 0
# 4500
# 0.176 4500
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 5000
# 0.176 5000
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 5500
# 0.126 5500
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 6000
# 0.126 6000
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 6500
# 0.102 6500
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 7000
# 0.102 7000
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 7500
# 0.076 7500
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 8000
# 0.076 8000
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 8500
# 0.102 8500
# susceptible= 494  infected= 1  infectious= 5 immune 0 quarantined 0
# 9000
# 0.152 9000
# susceptible= 493  infected= 2  infectious= 5 immune 0 quarantined 0
# 9500
# 0.176 9500
# susceptible= 493  infected= 2  infectious= 5 immune 0 quarantined 0
# 10000
# 0.176 10000
# susceptible= 493  infected= 2  infectious= 5 immune 0 quarantined 0
# 10500
# 0.152 10500
# susceptible= 493  infected= 2  infectious= 5 immune 0 quarantined 0
# 11000
# 0.126 11000
# susceptible= 493  infected= 2  infectious= 5 immune 0 quarantined 0
# 11500
# 0.076 11500
# susceptible= 493  infected= 2  infectious= 5 immune 0 quarantined 0
# i told him to leave 7
# i told him to leave 8
# i told him to leave 26
# i told him to leave 46
# i told him to leave 69
# i told him to leave 86
# i told him to leave 87
# i told him to leave 130
# i told him to leave 131
# i told him to leave 141
# i told him to leave 153
# i told him to leave 157
# i told him to leave 168
# i told him to leave 171
# i told him to leave 173
# i told him to leave 175
# i told him to leave 179
# i told him to leave 200
# i told him to leave 201
# i told him to leave 214
# i told him to leave 223
# i told him to leave 227
# i told him to leave 235
# i told him to leave 252
# i told him to leave 259
# i told him to leave 269
# i told him to leave 280
# i told him to leave 295
# i told him to leave 296
# i told him to leave 307
# i told him to leave 316
# i told him to leave 318
# i told him to leave 339
# i told him to leave 346
# i told him to leave 357
# i told him to leave 361
# i told him to leave 363
# i told him to leave 406
# i told him to leave 414
# i told him to leave 430
# i told him to leave 431
# i told him to leave 439
# i told him to leave 461
# i told him to leave 464
# i told him to leave 466
# i told him to leave 469
# i told him to leave 485
# i told him to leave 491
# i told him to leave 499
# new 2 infected people
# fr 500
# frequencyOfWalks 2.042
# 0
# 0.118 0
# susceptible= 493  infected= 0  infectious= 7 immune 0 quarantined 0
# 500
# 0.098 500
# susceptible= 491  infected= 2  infectious= 7 immune 0 quarantined 0
# 1000
# 0.012 1000
# susceptible= 491  infected= 2  infectious= 7 immune 0 quarantined 0
# 1500
# 0.006 1500
# susceptible= 491  infected= 2  infectious= 7 immune 0 quarantined 0
# 2000
# 0.006 2000
# susceptible= 491  infected= 2  infectious= 7 immune 0 quarantined 0
# 2500
# 0.006 2500
# susceptible= 491  infected= 2  infectious= 7 immune 0 quarantined 0
# 3000
# 0.012 3000
# susceptible= 491  infected= 2  infectious= 7 immune 0 quarantined 0
# 3500
# 0.052 3500
# susceptible= 491  infected= 2  infectious= 7 immune 0 quarantined 0
# 4000
# 0.176 4000
# susceptible= 491  infected= 2  infectious= 7 immune 0 quarantined 0
# 4500
# 0.176 4500
# susceptible= 490  infected= 3  infectious= 7 immune 0 quarantined 0
# 5000
# 0.176 5000
# susceptible= 489  infected= 4  infectious= 7 immune 0 quarantined 0
# 5500
# 0.126 5500
# susceptible= 489  infected= 4  infectious= 7 immune 0 quarantined 0
# 6000
# 0.126 6000
# susceptible= 489  infected= 4  infectious= 7 immune 0 quarantined 0
# 6500
# 0.102 6500
# susceptible= 489  infected= 4  infectious= 7 immune 0 quarantined 0
# 7000
# 0.102 7000
# susceptible= 489  infected= 4  infectious= 7 immune 0 quarantined 0
# 7500
# 0.076 7500
# susceptible= 489  infected= 4  infectious= 7 immune 0 quarantined 0
# 8000
# 0.076 8000
# susceptible= 489  infected= 4  infectious= 7 immune 0 quarantined 0
# 8500
# 0.102 8500
# susceptible= 488  infected= 5  infectious= 7 immune 0 quarantined 0
# 9000
# 0.152 9000
# susceptible= 488  infected= 5  infectious= 7 immune 0 quarantined 0
# 9500
# 0.176 9500
# susceptible= 488  infected= 5  infectious= 7 immune 0 quarantined 0
# 10000
# 0.176 10000
# susceptible= 488  infected= 5  infectious= 7 immune 0 quarantined 0
# 10500
# 0.152 10500
# susceptible= 488  infected= 5  infectious= 7 immune 0 quarantined 0
# 11000
# 0.126 11000
# susceptible= 488  infected= 5  infectious= 7 immune 0 quarantined 0
# 11500
# 0.076 11500
# susceptible= 488  infected= 5  infectious= 7 immune 0 quarantined 0
# i told him to leave 10
# i told him to leave 22
# i told him to leave 37
# i told him to leave 44
# i told him to leave 56
# i told him to leave 69
# i told him to leave 75
# i told him to leave 79
# i told him to leave 86
# i told him to leave 88
# i told him to leave 91
# i told him to leave 97
# i told him to leave 108
# i told him to leave 120
# i told him to leave 130
# i told him to leave 154
# i told him to leave 157
# i told him to leave 161
# i told him to leave 171
# i told him to leave 175
# i told him to leave 185
# i told him to leave 188
# i told him to leave 194
# i told him to leave 204
# i told him to leave 252
# i told him to leave 259
# i told him to leave 260
# i told him to leave 280
# i told him to leave 283
# i told him to leave 286
# i told him to leave 317
# i told him to leave 320
# i told him to leave 321
# i told him to leave 339
# i told him to leave 353
# i told him to leave 356
# i told him to leave 358
# i told him to leave 361
# i told him to leave 362
# i told him to leave 363
# i told him to leave 368
# i told him to leave 375
# i told him to leave 389
# i told him to leave 401
# i told him to leave 403
# i told him to leave 406
# i told him to leave 411
# i told him to leave 427
# i told him to leave 429
# i told him to leave 433
# i told him to leave 436
# i told him to leave 437
# i told him to leave 442
# i told him to leave 450
# i told him to leave 466
# i told him to leave 481
# new 5 infected people
# fr 500
# frequencyOfWalks 2.066
# 0
# 0.134 0
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 500
# 0.112 500
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 1000
# 0.012 1000
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 1500
# 0.006 1500
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 2000
# 0.006 2000
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 2500
# 0.006 2500
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 3000
# 0.012 3000
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 3500
# 0.052 3500
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 4000
# 0.176 4000
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 4500
# 0.176 4500
# susceptible= 488  infected= 0  infectious= 12 immune 0 quarantined 0
# 5000
# 0.176 5000
# susceptible= 487  infected= 1  infectious= 12 immune 0 quarantined 0
# 5500
# 0.126 5500
# susceptible= 487  infected= 1  infectious= 12 immune 0 quarantined 0
# 6000
# 0.126 6000
# susceptible= 487  infected= 1  infectious= 12 immune 0 quarantined 0
# 6500
# 0.102 6500
# susceptible= 487  infected= 1  infectious= 12 immune 0 quarantined 0
# 7000
# 0.102 7000
# susceptible= 487  infected= 1  infectious= 12 immune 0 quarantined 0
# 7500
# 0.076 7500
# susceptible= 487  infected= 1  infectious= 12 immune 0 quarantined 0
# 8000
# 0.076 8000
# susceptible= 485  infected= 3  infectious= 12 immune 0 quarantined 0
# 8500
# 0.102 8500
# susceptible= 485  infected= 3  infectious= 12 immune 0 quarantined 0
# 9000
# 0.152 9000
# susceptible= 485  infected= 3  infectious= 12 immune 0 quarantined 0
# 9500
# 0.176 9500
# susceptible= 485  infected= 3  infectious= 12 immune 0 quarantined 0
# 10000
# 0.176 10000
# susceptible= 485  infected= 3  infectious= 12 immune 0 quarantined 0
# 10500
# 0.152 10500
# susceptible= 484  infected= 4  infectious= 12 immune 0 quarantined 0
# 11000
# 0.112 11000
# susceptible= 484  infected= 4  infectious= 12 immune 0 quarantined 51
# 11500
# 0.076 11500
# susceptible= 484  infected= 4  infectious= 12 immune 0 quarantined 51
# i told him to leave 15
# i told him to leave 20
# i told him to leave 22
# i told him to leave 36
# i told him to leave 44
# i told him to leave 46
# i told him to leave 61
# i told him to leave 70
# i told him to leave 72
# i told him to leave 79
# i told him to leave 83
# i told him to leave 84
# i told him to leave 86
# i told him to leave 87
# i told him to leave 95
# i told him to leave 97
# i told him to leave 103
# i told him to leave 107
# i told him to leave 109
# i told him to leave 137
# i told him to leave 139
# i told him to leave 146
# i told him to leave 147
# i told him to leave 157
# i told him to leave 159
# i told him to leave 161
# i told him to leave 168
# i told him to leave 172
# i told him to leave 177
# i told him to leave 182
# i told him to leave 187
# i told him to leave 189
# i told him to leave 201
# i told him to leave 205
# i told him to leave 228
# i told him to leave 251
# i told him to leave 257
# i told him to leave 260
# i told him to leave 273
# i told him to leave 281
# i told him to leave 283
# i told him to leave 286
# i told him to leave 294
# i told him to leave 297
# i told him to leave 302
# i told him to leave 305
# i told him to leave 308
# i told him to leave 309
# i told him to leave 313
# i told him to leave 315
# i told him to leave 323
# i told him to leave 328
# i told him to leave 337
# i told him to leave 346
# i told him to leave 347
# i told him to leave 358
# i told him to leave 362
# i told him to leave 370
# i told him to leave 374
# i told him to leave 375
# i told him to leave 376
# i told him to leave 382
# i told him to leave 388
# i told him to leave 401
# i told him to leave 403
# i told him to leave 416
# i told him to leave 426
# i told him to leave 429
# i told him to leave 430
# i told him to leave 439
# i told him to leave 447
# i told him to leave 452
# i told him to leave 458
# i told him to leave 464
# i told him to leave 465
# i told him to leave 468
# i told him to leave 472
# i told him to leave 473
# i told him to leave 478
# i told him to leave 483
# i told him to leave 485
# i told him to leave 491
# new 4 infected people
# fr 449
# frequencyOfWalks 2.287305122494432
# 0
# 0.186 0
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 500
# 0.164 500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 1000
# 0.024 1000
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 1500
# 0.024 1500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 2000
# 0.024 2000
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 2500
# 0.024 2500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 3000
# 0.024 3000
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 3500
# 0.052 3500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 4000
# 0.176 4000
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 4500
# 0.176 4500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 5000
# 0.176 5000
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 5500
# 0.126 5500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 6000
# 0.126 6000
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 6500
# 0.102 6500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 7000
# 0.102 7000
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 7500
# 0.076 7500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 8000
# 0.076 8000
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 8500
# 0.102 8500
# susceptible= 484  infected= 0  infectious= 16 immune 0 quarantined 51
# 9000
# 0.152 9000
# susceptible= 483  infected= 1  infectious= 16 immune 0 quarantined 51
# 9500
# 0.176 9500
# susceptible= 483  infected= 1  infectious= 16 immune 0 quarantined 51
# 10000
# 0.176 10000
# susceptible= 483  infected= 1  infectious= 16 immune 0 quarantined 51
# 10500
# 0.152 10500
# susceptible= 483  infected= 1  infectious= 16 immune 0 quarantined 51
# 11000
# 0.122 11000
# susceptible= 483  infected= 1  infectious= 16 immune 0 quarantined 73
# 11500
# 0.076 11500
# susceptible= 483  infected= 1  infectious= 16 immune 0 quarantined 73
# i told him to leave 14
# i told him to leave 15
# i told him to leave 23
# i told him to leave 36
# i told him to leave 37
# i told him to leave 44
# i told him to leave 48
# i told him to leave 64
# i told him to leave 65
# i told him to leave 68
# i told him to leave 69
# i told him to leave 72
# i told him to leave 80
# i told him to leave 83
# i told him to leave 88
# i told him to leave 91
# i told him to leave 139
# i told him to leave 148
# i told him to leave 177
# i told him to leave 188
# i told him to leave 205
# i told him to leave 211
# i told him to leave 225
# i told him to leave 227
# i told him to leave 230
# i told him to leave 237
# i told him to leave 241
# i told him to leave 251
# i told him to leave 258
# i told him to leave 286
# i told him to leave 294
# i told him to leave 296
# i told him to leave 297
# i told him to leave 314
# i told him to leave 318
# i told him to leave 322
# i told him to leave 329
# i told him to leave 338
# i told him to leave 344
# i told him to leave 346
# i told him to leave 347
# i told him to leave 356
# i told him to leave 357
# i told him to leave 361
# i told him to leave 368
# i told him to leave 374
# i told him to leave 376
# i told him to leave 387
# i told him to leave 401
# i told him to leave 414
# i told him to leave 431
# i told him to leave 447
# i told him to leave 450
# i told him to leave 457
# i told him to leave 464
# i told him to leave 472
# i told him to leave 485
# i told him to leave 488
# new 1 infected people
# fr 427
# frequencyOfWalks 1.9133489461358313
# 0
# 0.13 0
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 500
# 0.128 500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 1000
# 0.04 1000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 1500
# 0.036 1500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 2000
# 0.036 2000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 2500
# 0.036 2500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 3000
# 0.036 3000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 3500
# 0.052 3500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 4000
# 0.176 4000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 4500
# 0.176 4500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 5000
# 0.176 5000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 5500
# 0.126 5500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 6000
# 0.126 6000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 6500
# 0.102 6500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 7000
# 0.102 7000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 7500
# 0.076 7500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 8000
# 0.076 8000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 8500
# 0.102 8500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 9000
# 0.152 9000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 9500
# 0.176 9500
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 10000
# 0.176 10000
# susceptible= 483  infected= 0  infectious= 17 immune 0 quarantined 73
# 10500
# 0.152 10500
# susceptible= 482  infected= 1  infectious= 17 immune 0 quarantined 73
# 11000
# 0.118 11000
# susceptible= 482  infected= 1  infectious= 17 immune 0 quarantined 91
# 11500
# 0.076 11500
# susceptible= 482  infected= 1  infectious= 17 immune 0 quarantined 91
# i told him to leave 8
# i told him to leave 22
# i told him to leave 26
# i told him to leave 31
# i told him to leave 36
# i told him to leave 37
# i told him to leave 44
# i told him to leave 68
# i told him to leave 69
# i told him to leave 75
# i told him to leave 83
# i told him to leave 84
# i told him to leave 88
# i told him to leave 91
# i told him to leave 99
# i told him to leave 100
# i told him to leave 102
# i told him to leave 109
# i told him to leave 124
# i told him to leave 139
# i told him to leave 141
# i told him to leave 153
# i told him to leave 154
# i told him to leave 171
# i told him to leave 177
# i told him to leave 180
# i told him to leave 182
# i told him to leave 188
# i told him to leave 193
# i told him to leave 198
# i told him to leave 223
# i told him to leave 224
# i told him to leave 228
# i told him to leave 235
# i told him to leave 238
# i told him to leave 241
# i told him to leave 251
# i told him to leave 254
# i told him to leave 258
# i told him to leave 259
# i told him to leave 261
# i told him to leave 273
# i told him to leave 274
# i told him to leave 294
# i told him to leave 296
# i told him to leave 297
# i told him to leave 302
# i told him to leave 317
# i told him to leave 322
# i told him to leave 324
# i told him to leave 331
# i told him to leave 339
# i told him to leave 346
# i told him to leave 354
# i told him to leave 357
# i told him to leave 363
# i told him to leave 372
# i told him to leave 374
# i told him to leave 376
# i told him to leave 382
# i told him to leave 387
# i told him to leave 388
# i told him to leave 389
# i told him to leave 402
# i told him to leave 403
# i told him to leave 411
# i told him to leave 412
# i told him to leave 413
# i told him to leave 431
# i told him to leave 435
# i told him to leave 437
# i told him to leave 443
# i told him to leave 445
# i told him to leave 448
# i told him to leave 450
# i told him to leave 451
# i told him to leave 464
# i told him to leave 473
# i told him to leave 478
# i told him to leave 480
# i told him to leave 488
# i told him to leave 491
# new 1 infected people
# fr 409
# frequencyOfWalks 1.7579462102689487
# 0
# 0.178 0
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 500
# 0.178 500
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 1000
# 0.06 1000
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 1500
# 0.06 1500
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 2000
# 0.06 2000
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 2500
# 0.06 2500
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 3000
# 0.06 3000
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 3500
# 0.06 3500
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 4000
# 0.176 4000
# susceptible= 482  infected= 0  infectious= 18 immune 0 quarantined 91
# 4500
# 0.176 4500
# susceptible= 481  infected= 1  infectious= 18 immune 0 quarantined 91
# 5000
# 0.176 5000
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 5500
# 0.126 5500
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 6000
# 0.126 6000
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 6500
# 0.102 6500
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 7000
# 0.102 7000
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 7500
# 0.076 7500
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 8000
# 0.076 8000
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 8500
# 0.102 8500
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 9000
# 0.152 9000
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 9500
# 0.176 9500
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 10000
# 0.176 10000
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 10500
# 0.152 10500
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 91
# 11000
# 0.122 11000
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 99
# 11500
# 0.076 11500
# susceptible= 479  infected= 3  infectious= 18 immune 0 quarantined 99
# i told him to leave 8
# i told him to leave 14
# i told him to leave 16
# i told him to leave 18
# i told him to leave 21
# i told him to leave 26
# i told him to leave 44
# i told him to leave 48
# i told him to leave 54
# i told him to leave 69
# i told him to leave 72
# i told him to leave 75
# i told him to leave 79
# i told him to leave 84
# i told him to leave 91
# i told him to leave 102
# i told him to leave 131
# i told him to leave 139
# i told him to leave 146
# i told him to leave 148
# i told him to leave 161
# i told him to leave 164
# i told him to leave 168
# i told him to leave 171
# i told him to leave 175
# i told him to leave 177
# i told him to leave 185
# i told him to leave 188
# i told him to leave 193
# i told him to leave 198
# i told him to leave 225
# i told him to leave 229
# i told him to leave 230
# i told him to leave 232
# i told him to leave 239
# i told him to leave 246
# i told him to leave 247
# i told him to leave 251
# i told him to leave 259
# i told him to leave 273
# i told him to leave 274
# i told him to leave 286
# i told him to leave 290
# i told him to leave 294
# i told him to leave 296
# i told him to leave 297
# i told him to leave 302
# i told him to leave 309
# i told him to leave 311
# i told him to leave 314
# i told him to leave 315
# i told him to leave 316
# i told him to leave 318
# i told him to leave 321
# i told him to leave 322
# i told him to leave 329
# i told him to leave 331
# i told him to leave 343
# i told him to leave 346
# i told him to leave 347
# i told him to leave 348
# i told him to leave 357
# i told him to leave 376
# i told him to leave 377
# i told him to leave 387
# i told him to leave 388
# i told him to leave 403
# i told him to leave 406
# i told him to leave 409
# i told him to leave 413
# i told him to leave 414
# i told him to leave 427
# i told him to leave 429
# i told him to leave 430
# i told him to leave 431
# i told him to leave 437
# i told him to leave 441
# i told him to leave 444
# i told him to leave 448
# i told him to leave 450
# i told him to leave 451
# i told him to leave 452
# i told him to leave 456
# i told him to leave 457
# i told him to leave 464
# i told him to leave 476
# i told him to leave 477
# i told him to leave 478
# i told him to leave 485
# i told him to leave 491
# i told him to leave 494
# i told him to leave 498
# new 3 infected people
# fr 401
# frequencyOfWalks 1.374064837905237
# 0
# 0.21 0
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 500
# 0.21 500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 1000
# 0.068 1000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 1500
# 0.066 1500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 2000
# 0.066 2000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 2500
# 0.066 2500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 3000
# 0.066 3000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 3500
# 0.066 3500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 4000
# 0.176 4000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 4500
# 0.176 4500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 5000
# 0.176 5000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 5500
# 0.126 5500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 6000
# 0.126 6000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 6500
# 0.102 6500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 7000
# 0.102 7000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 7500
# 0.076 7500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 8000
# 0.076 8000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 8500
# 0.102 8500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 9000
# 0.152 9000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 9500
# 0.176 9500
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 10000
# 0.176 10000
# susceptible= 479  infected= 0  infectious= 21 immune 0 quarantined 99
# 10500
# 0.152 10500
# susceptible= 478  infected= 1  infectious= 21 immune 0 quarantined 99
# 11000
# 0.12 11000
# susceptible= 478  infected= 1  infectious= 21 immune 0 quarantined 116
# 11500
# 0.076 11500
# susceptible= 478  infected= 1  infectious= 21 immune 0 quarantined 116
# i told him to leave 7
# i told him to leave 8
# i told him to leave 10
# i told him to leave 13
# i told him to leave 14
# i told him to leave 44
# i told him to leave 46
# i told him to leave 48
# i told him to leave 69
# i told him to leave 72
# i told him to leave 73
# i told him to leave 75
# i told him to leave 83
# i told him to leave 84
# i told him to leave 87
# i told him to leave 88
# i told him to leave 91
# i told him to leave 97
# i told him to leave 103
# i told him to leave 132
# i told him to leave 137
# i told him to leave 139
# i told him to leave 146
# i told him to leave 152
# i told him to leave 154
# i told him to leave 159
# i told him to leave 162
# i told him to leave 164
# i told him to leave 167
# i told him to leave 171
# i told him to leave 175
# i told him to leave 177
# i told him to leave 185
# i told him to leave 187
# i told him to leave 188
# i told him to leave 189
# i told him to leave 190
# i told him to leave 196
# i told him to leave 200
# i told him to leave 215
# i told him to leave 227
# i told him to leave 228
# i told him to leave 229
# i told him to leave 230
# i told him to leave 232
# i told him to leave 238
# i told him to leave 241
# i told him to leave 245
# i told him to leave 246
# i told him to leave 247
# i told him to leave 251
# i told him to leave 254
# i told him to leave 257
# i told him to leave 261
# i told him to leave 269
# i told him to leave 274
# i told him to leave 294
# i told him to leave 296
# i told him to leave 297
# i told him to leave 302
# i told him to leave 307
# i told him to leave 317
# i told him to leave 318
# i told him to leave 320
# i told him to leave 322
# i told him to leave 323
# i told him to leave 331
# i told him to leave 338
# i told him to leave 339
# i told him to leave 340
# i told him to leave 344
# i told him to leave 346
# i told him to leave 347
# i told him to leave 348
# i told him to leave 353
# i told him to leave 360
# i told him to leave 372
# i told him to leave 374
# i told him to leave 377
# i told him to leave 379
# i told him to leave 387
# i told him to leave 399
# i told him to leave 401
# i told him to leave 403
# i told him to leave 412
# i told him to leave 413
# i told him to leave 427
# i told him to leave 431
# i told him to leave 437
# i told him to leave 441
# i told him to leave 443
# i told him to leave 446
# i told him to leave 447
# i told him to leave 450
# i told him to leave 451
# i told him to leave 452
# i told him to leave 456
# i told him to leave 464
# i told him to leave 466
# i told him to leave 485
# i told him to leave 491
# i told him to leave 498
# new 1 infected people
# fr 384
# frequencyOfWalks 1.3020833333333333
# 0
# 0.224 0
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 500
# 0.222 500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 1000
# 0.086 1000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 1500
# 0.082 1500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 2000
# 0.082 2000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 2500
# 0.082 2500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 3000
# 0.082 3000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 3500
# 0.082 3500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 4000
# 0.176 4000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 4500
# 0.176 4500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 5000
# 0.176 5000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 5500
# 0.126 5500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 6000
# 0.126 6000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 6500
# 0.102 6500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 7000
# 0.102 7000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 7500
# 0.084 7500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 8000
# 0.082 8000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 8500
# 0.102 8500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 9000
# 0.152 9000
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 9500
# 0.176 9500
# susceptible= 478  infected= 0  infectious= 22 immune 0 quarantined 116
# 10000
# 0.176 10000
# susceptible= 476  infected= 2  infectious= 22 immune 0 quarantined 116
# 10500
# 0.152 10500
# susceptible= 475  infected= 3  infectious= 22 immune 0 quarantined 116
# 11000
# 0.122 11000
# susceptible= 475  infected= 3  infectious= 22 immune 0 quarantined 116
# 11500
# 0.078 11500
# susceptible= 475  infected= 3  infectious= 22 immune 0 quarantined 116
# i told him to leave 7
# i told him to leave 14
# i told him to leave 15
# i told him to leave 20
# i told him to leave 26
# i told him to leave 32
# i told him to leave 36
# i told him to leave 44
# i told him to leave 46
# i told him to leave 58
# i told him to leave 69
# i told him to leave 75
# i told him to leave 80
# i told him to leave 88
# i told him to leave 91
# i told him to leave 97
# i told him to leave 102
# i told him to leave 103
# i told him to leave 109
# i told him to leave 116
# i told him to leave 132
# i told him to leave 137
# i told him to leave 139
# i told him to leave 140
# i told him to leave 144
# i told him to leave 146
# i told him to leave 148
# i told him to leave 163
# i told him to leave 166
# i told him to leave 169
# i told him to leave 173
# i told him to leave 177
# i told him to leave 180
# i told him to leave 186
# i told him to leave 187
# i told him to leave 188
# i told him to leave 193
# i told him to leave 198
# i told him to leave 201
# i told him to leave 206
# i told him to leave 215
# i told him to leave 223
# i told him to leave 227
# i told him to leave 228
# i told him to leave 229
# i told him to leave 230
# i told him to leave 235
# i told him to leave 238
# i told him to leave 243
# i told him to leave 246
# i told him to leave 251
# i told him to leave 257
# i told him to leave 259
# i told him to leave 274
# i told him to leave 287
# i told him to leave 294
# i told him to leave 296
# i told him to leave 297
# i told him to leave 298
# i told him to leave 302
# i told him to leave 305
# i told him to leave 313
# i told him to leave 314
# i told him to leave 318
# i told him to leave 322
# i told him to leave 323
# i told him to leave 329
# i told him to leave 331
# i told him to leave 337
# i told him to leave 339
# i told him to leave 340
# i told him to leave 346
# i told him to leave 347
# i told him to leave 348
# i told him to leave 356
# i told him to leave 358
# i told him to leave 360
# i told him to leave 363
# i told him to leave 368
# i told him to leave 372
# i told him to leave 373
# i told him to leave 375
# i told him to leave 388
# i told him to leave 399
# i told him to leave 409
# i told him to leave 410
# i told him to leave 411
# i told him to leave 412
# i told him to leave 418
# i told him to leave 420
# i told him to leave 426
# i told him to leave 427
# i told him to leave 429
# i told him to leave 430
# i told him to leave 437
# i told him to leave 441
# i told him to leave 446
# i told him to leave 450
# i told him to leave 451
# i told him to leave 456
# i told him to leave 457
# i told him to leave 464
# i told him to leave 465
# i told him to leave 466
# i told him to leave 475
# i told him to leave 483
# i told him to leave 487
# i told him to leave 491
# new 3 infected people
# fr 384
# frequencyOfWalks 1.0286458333333333
# 0
# 0.238 0
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 500
# 0.238 500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 1000
# 0.092 1000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 1500
# 0.092 1500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 2000
# 0.092 2000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 2500
# 0.092 2500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 3000
# 0.092 3000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 3500
# 0.092 3500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 4000
# 0.176 4000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 4500
# 0.176 4500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 5000
# 0.176 5000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 5500
# 0.126 5500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 6000
# 0.126 6000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 6500
# 0.102 6500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 7000
# 0.102 7000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 7500
# 0.092 7500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 8000
# 0.092 8000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 8500
# 0.102 8500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 9000
# 0.152 9000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 9500
# 0.176 9500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 10000
# 0.176 10000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 10500
# 0.152 10500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 116
# 11000
# 0.126 11000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 11500
# 0.092 11500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# i told him to leave 7
# i told him to leave 14
# i told him to leave 20
# i told him to leave 21
# i told him to leave 23
# i told him to leave 26
# i told him to leave 36
# i told him to leave 44
# i told him to leave 54
# i told him to leave 69
# i told him to leave 72
# i told him to leave 75
# i told him to leave 80
# i told him to leave 91
# i told him to leave 97
# i told him to leave 102
# i told him to leave 103
# i told him to leave 109
# i told him to leave 124
# i told him to leave 132
# i told him to leave 137
# i told him to leave 139
# i told him to leave 146
# i told him to leave 153
# i told him to leave 173
# i told him to leave 177
# i told him to leave 186
# i told him to leave 187
# i told him to leave 188
# i told him to leave 201
# i told him to leave 204
# i told him to leave 210
# i told him to leave 215
# i told him to leave 223
# i told him to leave 225
# i told him to leave 227
# i told him to leave 228
# i told him to leave 235
# i told him to leave 238
# i told him to leave 251
# i told him to leave 257
# i told him to leave 258
# i told him to leave 259
# i told him to leave 269
# i told him to leave 274
# i told him to leave 283
# i told him to leave 294
# i told him to leave 296
# i told him to leave 297
# i told him to leave 302
# i told him to leave 305
# i told him to leave 317
# i told him to leave 318
# i told him to leave 321
# i told him to leave 322
# i told him to leave 324
# i told him to leave 328
# i told him to leave 329
# i told him to leave 331
# i told him to leave 337
# i told him to leave 338
# i told him to leave 339
# i told him to leave 340
# i told him to leave 341
# i told him to leave 346
# i told him to leave 348
# i told him to leave 356
# i told him to leave 360
# i told him to leave 361
# i told him to leave 368
# i told him to leave 370
# i told him to leave 372
# i told him to leave 373
# i told him to leave 376
# i told him to leave 379
# i told him to leave 402
# i told him to leave 409
# i told him to leave 412
# i told him to leave 418
# i told him to leave 427
# i told him to leave 430
# i told him to leave 431
# i told him to leave 435
# i told him to leave 437
# i told him to leave 441
# i told him to leave 444
# i told him to leave 446
# i told him to leave 448
# i told him to leave 449
# i told him to leave 450
# i told him to leave 451
# i told him to leave 456
# i told him to leave 464
# i told him to leave 465
# i told him to leave 466
# i told him to leave 483
# i told him to leave 487
# i told him to leave 488
# i told him to leave 494
# new 0 infected people
# fr 376
# frequencyOfWalks 0.8829787234042553
# 0
# 0.218 0
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 500
# 0.218 500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 1000
# 0.1 1000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 1500
# 0.1 1500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 2000
# 0.1 2000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 2500
# 0.1 2500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 3000
# 0.1 3000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 3500
# 0.1 3500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 4000
# 0.176 4000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 4500
# 0.176 4500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 5000
# 0.176 5000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 5500
# 0.126 5500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 6000
# 0.126 6000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 6500
# 0.102 6500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 7000
# 0.102 7000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 7500
# 0.1 7500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 8000
# 0.1 8000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 8500
# 0.102 8500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 9000
# 0.152 9000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 9500
# 0.176 9500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 10000
# 0.176 10000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 10500
# 0.152 10500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 124
# 11000
# 0.12 11000
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 135
# 11500
# 0.098 11500
# susceptible= 475  infected= 0  infectious= 25 immune 0 quarantined 135
# i told him to leave 7
# ...
# i told him to leave 116
# i told him to leave 131
# i told him to leave 132
# i told him to leave 137
# i told him to leave 139
# i told him to leave 140
# i told him to leave 147
# i told him to leave 154
# i told him to leave 162
# i told him to leave 163
# i told him to leave 166
# i told him to leave 167
# i told him to leave 171
# i told him to leave 172
# i told him to leave 173
# i told him to leave 175
# i told him to leave 180
# i told him to leave 182
# i told him to leave 185
# i told him to leave 187
# i told him to leave 189
# i told him to leave 198
# i told him to leave 200
# i told him to leave 210
# i told him to leave 214
# i told him to leave 215
# i told him to leave 225
# i told him to leave 228
# i told him to leave 229
# i told him to leave 237
# i told him to leave 238
# i told him to leave 241
# i told him to leave 260
# i told him to leave 261
# i told him to leave 264
# i told him to leave 266
# i told him to leave 268
# i told him to leave 269
# i told him to leave 270
# i told him to leave 274
# i told him to leave 275
# i told him to leave 290
# i told him to leave 295
# i told him to leave 296
# i told him to leave 297
# i told him to leave 298
# i told him to leave 304
# i told him to leave 305
# i told him to leave 307
# i told him to leave 308
# i told him to leave 309
# i told him to leave 315
# i told him to leave 320
# i told him to leave 324
# i told him to leave 329
# i told him to leave 338
# i told him to leave 339
# i told him to leave 340
# i told him to leave 341
# i told him to leave 343
# i told him to leave 344
# i told him to leave 346
# i told him to leave 348
# i told him to leave 353
# i told him to leave 358
# i told him to leave 360
# i told him to leave 362
# i told him to leave 363
# i told him to leave 370
# i told him to leave 372
# i told him to leave 375
# i told him to leave 378
# i told him to leave 379
# i told him to leave 397
# i told him to leave 401
# i told him to leave 405
# i told him to leave 412
# i told him to leave 416
# i told him to leave 418
# i told him to leave 419
# i told him to leave 427
# i told him to leave 430
# i told him to leave 431
# i told him to leave 433
# i told him to leave 435
# i told him to leave 437
# i told him to leave 441
# i told him to leave 445
# i told him to leave 446
# i told him to leave 447
# i told him to leave 448
# i told him to leave 450
# i told him to leave 451
# i told him to leave 452
# i told him to leave 457
# i told him to leave 470
# i told him to leave 477
# i told him to leave 478
# i told him to leave 480
# i told him to leave 488
# i told him to leave 491
# i told him to leave 498
# new 0 infected people
# fr 364
# frequencyOfWalks 0.11538461538461539
# 0
# 0.31 0
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 500
# 0.31 500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 1000
# 0.16 1000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 1500
# 0.16 1500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 2000
# 0.16 2000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 2500
# 0.16 2500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 3000
# 0.16 3000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 3500
# 0.16 3500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 4000
# 0.176 4000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 4500
# 0.176 4500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 5000
# 0.176 5000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 5500
# 0.162 5500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 6000
# 0.16 6000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 6500
# 0.16 6500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 7000
# 0.16 7000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 7500
# 0.16 7500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 8000
# 0.16 8000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 8500
# 0.16 8500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 9000
# 0.16 9000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 9500
# 0.176 9500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 10000
# 0.176 10000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 10500
# 0.162 10500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 11000
# 0.16 11000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 11500
# 0.16 11500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# i told him to leave 7
# i told him to leave 8
# i told him to leave 10
# i told him to leave 14
# i told him to leave 15
# i told him to leave 20
# i told him to leave 22
# i told him to leave 23
# i told him to leave 26
# i told him to leave 33
# i told him to leave 34
# i told him to leave 44
# i told him to leave 46
# i told him to leave 48
# i told him to leave 65
# i told him to leave 84
# i told him to leave 86
# i told him to leave 91
# i told him to leave 97
# i told him to leave 100
# i told him to leave 102
# i told him to leave 104
# i told him to leave 107
# i told him to leave 108
# i told him to leave 109
# i told him to leave 114
# i told him to leave 131
# i told him to leave 132
# i told him to leave 139
# i told him to leave 140
# i told him to leave 147
# i told him to leave 162
# i told him to leave 163
# i told him to leave 166
# i told him to leave 167
# i told him to leave 173
# i told him to leave 175
# i told him to leave 180
# i told him to leave 185
# i told him to leave 187
# i told him to leave 189
# i told him to leave 196
# i told him to leave 200
# i told him to leave 215
# i told him to leave 222
# i told him to leave 229
# i told him to leave 237
# i told him to leave 238
# i told him to leave 243
# i told him to leave 261
# i told him to leave 266
# i told him to leave 268
# i told him to leave 269
# i told him to leave 274
# i told him to leave 295
# i told him to leave 296
# i told him to leave 297
# i told him to leave 304
# i told him to leave 305
# i told him to leave 307
# i told him to leave 308
# i told him to leave 315
# i told him to leave 324
# i told him to leave 328
# i told him to leave 338
# i told him to leave 339
# i told him to leave 340
# i told him to leave 341
# i told him to leave 343
# i told him to leave 346
# i told him to leave 353
# i told him to leave 357
# i told him to leave 358
# i told him to leave 362
# i told him to leave 363
# i told him to leave 370
# i told him to leave 372
# i told him to leave 378
# i told him to leave 379
# i told him to leave 393
# i told him to leave 397
# i told him to leave 401
# i told him to leave 403
# i told him to leave 405
# i told him to leave 412
# i told him to leave 414
# i told him to leave 418
# i told him to leave 419
# i told him to leave 427
# i told him to leave 430
# i told him to leave 431
# i told him to leave 433
# i told him to leave 435
# i told him to leave 437
# i told him to leave 445
# i told him to leave 446
# i told him to leave 447
# i told him to leave 450
# i told him to leave 451
# i told him to leave 452
# i told him to leave 456
# i told him to leave 470
# i told him to leave 478
# i told him to leave 480
# i told him to leave 485
# i told him to leave 491
# new 0 infected people
# fr 364
# frequencyOfWalks 0.11538461538461539
# 0
# 0.264 0
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 500
# 0.264 500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 1000
# 0.162 1000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 1500
# 0.162 1500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 2000
# 0.162 2000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 2500
# 0.162 2500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 3000
# 0.162 3000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 3500
# 0.162 3500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 4000
# 0.176 4000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 4500
# 0.176 4500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 5000
# 0.176 5000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 5500
# 0.162 5500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 6000
# 0.162 6000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 6500
# 0.162 6500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 7000
# 0.162 7000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 7500
# 0.162 7500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 8000
# 0.162 8000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 8500
# 0.162 8500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 9000
# 0.162 9000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 9500
# 0.176 9500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 10000
# 0.176 10000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 10500
# 0.162 10500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 11000
# 0.162 11000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 11500
# 0.162 11500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# i told him to leave 7
# i told him to leave 8
# i told him to leave 10
# i told him to leave 14
# i told him to leave 15
# i told him to leave 20
# i told him to leave 22
# i told him to leave 23
# i told him to leave 33
# i told him to leave 34
# i told him to leave 44
# i told him to leave 65
# i told him to leave 84
# i told him to leave 86
# i told him to leave 91
# i told him to leave 97
# i told him to leave 100
# i told him to leave 102
# i told him to leave 104
# i told him to leave 107
# i told him to leave 109
# i told him to leave 114
# i told him to leave 121
# i told him to leave 132
# i told him to leave 139
# i told him to leave 140
# i told him to leave 154
# i told him to leave 163
# i told him to leave 166
# i told him to leave 171
# i told him to leave 173
# i told him to leave 175
# i told him to leave 180
# i told him to leave 185
# i told him to leave 187
# i told him to leave 189
# i told him to leave 196
# i told him to leave 200
# i told him to leave 215
# i told him to leave 223
# i told him to leave 224
# i told him to leave 225
# i told him to leave 229
# i told him to leave 238
# i told him to leave 264
# i told him to leave 266
# i told him to leave 268
# i told him to leave 269
# i told him to leave 274
# i told him to leave 296
# i told him to leave 297
# i told him to leave 298
# i told him to leave 305
# i told him to leave 308
# i told him to leave 311
# i told him to leave 315
# i told him to leave 328
# i told him to leave 329
# i told him to leave 338
# i told him to leave 339
# i told him to leave 340
# i told him to leave 341
# i told him to leave 343
# i told him to leave 346
# i told him to leave 353
# i told him to leave 358
# i told him to leave 362
# i told him to leave 363
# i told him to leave 370
# i told him to leave 372
# i told him to leave 378
# i told him to leave 397
# i told him to leave 401
# i told him to leave 405
# i told him to leave 412
# i told him to leave 418
# i told him to leave 427
# i told him to leave 430
# i told him to leave 433
# i told him to leave 435
# i told him to leave 437
# i told him to leave 445
# i told him to leave 446
# i told him to leave 450
# i told him to leave 451
# i told him to leave 452
# i told him to leave 480
# i told him to leave 485
# i told him to leave 491
# new 0 infected people
# fr 364
# frequencyOfWalks 0.09615384615384616
# 0
# 0.23 0
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 500
# 0.23 500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 1000
# 0.166 1000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 1500
# 0.162 1500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 2000
# 0.162 2000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 2500
# 0.162 2500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 3000
# 0.162 3000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 3500
# 0.162 3500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 4000
# 0.176 4000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 4500
# 0.176 4500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 5000
# 0.176 5000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 5500
# 0.162 5500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 6000
# 0.162 6000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 6500
# 0.162 6500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 7000
# 0.162 7000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 7500
# 0.162 7500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 8000
# 0.162 8000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 8500
# 0.162 8500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 9000
# 0.162 9000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 9500
# 0.176 9500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 10000
# 0.176 10000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 10500
# 0.162 10500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 11000
# 0.162 11000
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# 11500
# 0.162 11500
# susceptible= 472  infected= 0  infectious= 1 immune 27 quarantined 136
# i told him to leave 7
# i told him to leave 10
# i told him to leave 14
# i told him to leave 15
# i told him to leave 22
# i told him to leave 32
# i told him to leave 34
# i told him to leave 44
# i told him to leave 47
# i told him to leave 65
# i told him to leave 86
# i told him to leave 91
# i told him to leave 97
# i told him to leave 100
# i told him to leave 102
# i told him to leave 114
# i told him to leave 116
# i told him to leave 124
# i told him to leave 132
# i told him to leave 139
# i told him to leave 140
# i told him to leave 166
# i told him to leave 167
# i told him to leave 175
# i told him to leave 180
# i told him to leave 185
# i told him to leave 187
# i told him to leave 189
# i told him to leave 196
# i told him to leave 198
# i told him to leave 200
# i told him to leave 210
# i told him to leave 215
# i told him to leave 222
# i told him to leave 223
# i told him to leave 224
# i told him to leave 225
# i told him to leave 235
# i told him to leave 237
# i told him to leave 238
# i told him to leave 251
# i told him to leave 260
# i told him to leave 266
# i told him to leave 268
# i told him to leave 269
# i told him to leave 275
# i told him to leave 296
# i told him to leave 297
# i told him to leave 298
# i told him to leave 302
# i told him to leave 305
# i told him to leave 308
# i told him to leave 311
# i told him to leave 313
# i told him to leave 314
# i told him to leave 315
# i told him to leave 316
# i told him to leave 320
# i told him to leave 328
# i told him to leave 339
# i told him to leave 340
# i told him to leave 341
# i told him to leave 343
# i told him to leave 346
# i told him to leave 353
# i told him to leave 358
# i told him to leave 362
# i told him to leave 363
# i told him to leave 370
# i told him to leave 371
# i told him to leave 372
# i told him to leave 375
# i told him to leave 378
# i told him to leave 388
# i told him to leave 397
# i told him to leave 405
# i told him to leave 411
# i told him to leave 412
# i told him to leave 418
# i told him to leave 419
# i told him to leave 420
# i told him to leave 427
# i told him to leave 431
# i told him to leave 433
# i told him to leave 435
# i told him to leave 437
# i told him to leave 439
# i told him to leave 445
# i told him to leave 446
# i told him to leave 450
# i told him to leave 451
# i told him to leave 456
# i told him to leave 457
# i told him to leave 480
# i told him to leave 485
# i told him to leave 499
# new 0 infected people
# fr 364
# frequencyOfWalks 0.09615384615384616
# 0
# 0.252 0
# susceptible= 472  infected= 0  infectious= 0 immune 28 quarantined 135
# Time:  3944.4995021999966

# %%
contactlist.close()
resultlist.close()
relationshipFile.close()
infoFile.close()
squaretext.close()
calc1=0
calc2=0
maxvalue=0
pointer=0
testarray=np.zeros(2000)
#print( days_ContactDictionary[0])
for j in range(0,len(days_ContactDictionary[0])):
    calc2=calc2+calc1
    calc1=0
    for i in days_ContactDictionary[0][j]:
        testarray[int(i[1])]=testarray[int(i[1])]+1
        #print(j)
        #print("--",i[1],i[0])
        if i[1]==126:
            #print(j)
            maxvalue=i[1]
            pointer=i[0]
        if i[0]>0:
            calc1=calc1+i[1]
    if calc1>0:
        calc1=calc1/(len(days_ContactDictionary[0][j])-1)
        
calc2=calc2/2000
print(people[10][9]) ## [235][9]
#print(calc2)
#print("max",maxvalue)
#print(pointer)
#print(days_ContactDictionary[0])
for i in range(0,len(testarray)-1):
    print(i,testarray[i])
# Out:
# ['122,9', '121,10', '122,11', '121,12', '121,13', '121,14', '121,15', '122,16', '122,17', '121,18', '120,19', '121,20', '120,21', '121,22', '121,23', '120,24', '120,25', '119,26', '120,27', '119,28', '119,29', '120,30', '120,31', '119,32', '120,33', '119,34', '119,35', '118,36', '118,37', '119,38', '118,39', '118,40', '118,41', '117,42', '116,43', '115,43', '114,44', '114,45', '115,46', '114,47', '115,48', '114,49', '113,50', '112,51', '113,52', '114,53', '113,54', '112,55', '113,56', '112,57', '113,58', '114,59', '113,60', '112,61', '113,62', '113,63', '112,64', '111,65', '112,66', '111,67', '110,68', '109,69', '108,70', '107,71', '106,72', '105,73', '104,72', '103,71', '102,71', '101,72', '100,73', '99,73', '98,73', '97,72', '96,72', '95,73', '94,72', '93,73', '92,73', '91,72', '90,71', '89,72', '88,72', '87,71', '86,72', '85,71', '84,72', '83,73', '82,74', '81,75', '80,76', '79,75', '78,74', '77,75', '76,76', '75,77', '74,78', '73,79']
# 0 0.0
# 1 78.0
# 2 1826.0
# 3 22.0
# 4 1886.0
# 5 2.0
# 6 134.0
# 7 6.0
# 8 86.0
# 9 2.0
# 10 34.0
# 11 4.0
# 12 28.0
# 13 2.0
# 14 34.0
# 15 2.0
# 16 20.0
# 17 0.0
# 18 20.0
# 19 2.0
# 20 10.0
# 21 4.0
# 22 12.0
# 23 2.0
# 24 12.0
# 25 4.0
# 26 14.0
# 27 2.0
# 28 14.0
# 29 0.0
# 30 12.0
# 31 2.0
# 32 6.0
# 33 0.0
# 34 2.0
# 35 0.0
# 36 2.0
# 37 0.0
# 38 12.0
# 39 0.0
# 40 8.0
# 41 0.0
# 42 8.0
# 43 0.0
# 44 2.0
# 45 2.0
# 46 4.0
# 47 2.0
# 48 0.0
# 49 0.0
# 50 2.0
# 51 0.0
# 52 2.0
# 53 2.0
# 54 4.0
# 55 0.0
# 56 4.0
# 57 2.0
# 58 2.0
# 59 0.0
# 60 0.0
# 61 0.0
# 62 2.0
# 63 0.0
# 64 4.0
# 65 0.0
# 66 0.0
# 67 0.0
# 68 2.0
# 69 0.0
# 70 4.0
# 71 0.0
# 72 2.0
# 73 0.0
# 74 2.0
# 75 0.0
# 76 0.0
# 77 0.0
# 78 0.0
# 79 0.0
# 80 2.0
# 81 0.0
# 82 0.0
# 83 0.0
# 84 0.0
# 85 0.0
# 86 0.0
# 87 0.0
# 88 0.0
# 89 0.0
# 90 0.0
# 91 0.0
# 92 0.0
# 93 0.0
# 94 0.0
# 95 2.0
# 96 0.0
# 97 0.0
# 98 4.0
# 99 0.0
# 100 0.0
# 101 0.0
# 102 0.0
# 103 0.0
# 104 0.0
# 105 0.0
# 106 2.0
# 107 0.0
# 108 0.0
# 109 0.0
# 110 0.0
# 111 0.0
# 112 0.0
# 113 0.0
# 114 0.0
# 115 0.0
# 116 0.0
# 117 0.0
# 118 2.0
# 119 0.0
# 120 0.0
# 121 0.0
# 122 2.0
# 123 0.0
# 124 0.0
# 125 0.0
# 126 0.0
# 127 0.0
# 128 0.0
# 129 0.0
# 130 2.0
# 131 0.0
# 132 0.0
# 133 0.0
# 134 0.0
# 135 0.0
# 136 0.0
# 137 0.0
# 138 0.0
# 139 0.0
# 140 2.0
# 141 0.0
# 142 0.0
# 143 0.0
# 144 0.0
# 145 0.0
# 146 0.0
# 147 0.0
# 148 0.0
# 149 0.0
# 150 0.0
# 151 0.0
# 152 0.0
# 153 0.0
# 154 0.0
# 155 0.0
# 156 0.0
# 157 0.0
# 158 0.0
# 159 0.0
# 160 0.0
# 161 0.0
# 162 0.0
# 163 0.0
# 164 0.0
# 165 0.0
# 166 2.0
# 167 0.0
# 168 0.0
# 169 0.0
# 170 0.0
# 171 0.0
# 172 0.0
# 173 0.0
# 174 0.0
# 175 0.0
# 176 0.0
# 177 0.0
# 178 0.0
# 179 0.0
# 180 0.0
# 181 0.0
# 182 0.0
# 183 0.0
# 184 0.0
# 185 0.0
# 186 0.0
# 187 0.0
# 188 0.0
# 189 0.0
# 190 0.0
# 191 0.0
# 192 0.0
# 193 0.0
# 194 0.0
# 195 0.0
# 196 0.0
# 197 0.0
# 198 0.0
# 199 0.0
# 200 0.0
# 201 0.0
# 202 0.0
# 203 0.0
# 204 0.0
# 205 0.0
# 206 0.0
# 207 0.0
# 208 0.0
# 209 0.0
# 210 0.0
# 211 0.0
# 212 0.0
# 213 0.0
# 214 0.0
# 215 0.0
# 216 0.0
# 217 0.0
# 218 0.0
# 219 0.0
# 220 0.0
# 221 0.0
# 222 0.0
# 223 0.0
# 224 0.0
# 225 0.0
# 226 0.0
# 227 0.0
# 228 0.0
# 229 0.0
# 230 0.0
# 231 0.0
# 232 0.0
# 233 0.0
# 234 0.0
# 235 0.0
# 236 0.0
# 237 0.0
# 238 0.0
# 239 0.0
# 240 0.0
# 241 0.0
# 242 0.0
# 243 0.0
# 244 0.0
# 245 0.0
# 246 0.0
# 247 0.0
# 248 0.0
# 249 0.0
# 250 0.0
# 251 0.0
# 252 0.0
# 253 0.0
# 254 0.0
# 255 0.0
# 256 0.0
# 257 0.0
# 258 0.0
# 259 0.0
# 260 0.0
# 261 0.0
# 262 0.0
# 263 0.0
# 264 0.0
# 265 0.0
# 266 0.0
# 267 0.0
# 268 0.0
# 269 0.0
# 270 0.0
# 271 0.0
# 272 0.0
# 273 0.0
# 274 0.0
# 275 0.0
# 276 0.0
# 277 0.0
# 278 0.0
# 279 0.0
# 280 0.0
# 281 0.0
# 282 0.0
# 283 0.0
# 284 0.0
# 285 0.0
# 286 0.0
# 287 0.0
# 288 0.0
# 289 0.0
# 290 0.0
# 291 0.0
# 292 0.0
# 293 0.0
# 294 0.0
# 295 0.0
# 296 0.0
# 297 0.0
# 298 0.0
# 299 0.0
# 300 0.0
# 301 0.0
# 302 0.0
# 303 0.0
# 304 0.0
# 305 0.0
# 306 0.0
# 307 0.0
# 308 0.0
# 309 0.0
# 310 0.0
# 311 0.0
# 312 0.0
# 313 0.0
# 314 0.0
# 315 0.0
# 316 0.0
# 317 0.0
# 318 0.0
# 319 0.0
# 320 0.0
# 321 0.0
# 322 0.0
# 323 0.0
# 324 0.0
# 325 0.0
# 326 0.0
# 327 0.0
# 328 0.0
# 329 0.0
# 330 0.0
# 331 0.0
# 332 0.0
# 333 0.0
# 334 0.0
# 335 0.0
# 336 0.0
# 337 0.0
# 338 0.0
# 339 0.0
# 340 0.0
# 341 0.0
# 342 0.0
# 343 0.0
# 344 0.0
# 345 0.0
# 346 0.0
# 347 0.0
# 348 0.0
# 349 0.0
# 350 0.0
# 351 0.0
# 352 0.0
# 353 0.0
# 354 0.0
# 355 0.0
# 356 0.0
# 357 0.0
# 358 0.0
# 359 0.0
# 360 0.0
# 361 0.0
# 362 0.0
# 363 0.0
# 364 0.0
# 365 0.0
# 366 0.0
# 367 0.0
# 368 0.0
# 369 0.0
# 370 0.0
# 371 0.0
# 372 0.0
# 373 0.0
# 374 0.0
# 375 0.0
# 376 0.0
# 377 0.0
# 378 0.0
# 379 0.0
# 380 0.0
# 381 0.0
# 382 0.0
# 383 0.0
# 384 0.0
# 385 0.0
# 386 0.0
# 387 0.0
# 388 0.0
# 389 0.0
# 390 0.0
# 391 0.0
# 392 0.0
# 393 0.0
# 394 0.0
# 395 0.0
# 396 0.0
# 397 0.0
# 398 0.0
# 399 0.0
# 400 0.0
# 401 0.0
# 402 0.0
# 403 0.0
# 404 0.0
# 405 0.0
# 406 0.0
# 407 0.0
# 408 0.0
# 409 0.0
# 410 0.0
# 411 0.0
# 412 0.0
# 413 0.0
# 414 0.0
# 415 0.0
# 416 0.0
# 417 0.0
# 418 0.0
# 419 0.0
# 420 0.0
# 421 0.0
# 422 0.0
# 423 0.0
# 424 0.0
# 425 0.0
# 426 0.0
# 427 0.0
# 428 0.0
# 429 0.0
# 430 0.0
# 431 0.0
# 432 0.0
# 433 0.0
# 434 0.0
# 435 0.0
# 436 0.0
# 437 0.0
# 438 0.0
# 439 0.0
# 440 0.0
# 441 0.0
# 442 0.0
# 443 0.0
# 444 0.0
# 445 0.0
# 446 0.0
# 447 0.0
# 448 0.0
# 449 0.0
# 450 0.0
# 451 0.0
# 452 0.0
# 453 0.0
# 454 0.0
# 455 0.0
# 456 0.0
# 457 0.0
# 458 0.0
# 459 0.0
# 460 0.0
# 461 0.0
# 462 0.0
# 463 0.0
# 464 0.0
# 465 0.0
# 466 0.0
# 467 0.0
# 468 0.0
# 469 0.0
# 470 0.0
# 471 0.0
# 472 0.0
# 473 0.0
# 474 0.0
# 475 0.0
# 476 0.0
# 477 0.0
# 478 0.0
# 479 0.0
# 480 0.0
# 481 0.0
# 482 0.0
# 483 0.0
# 484 0.0
# 485 0.0
# 486 0.0
# 487 0.0
# 488 0.0
# 489 0.0
# 490 0.0
# 491 0.0
# 492 0.0
# 493 0.0
# 494 0.0
# 495 0.0
# 496 0.0
# 497 0.0
# 498 0.0
# 499 0.0
# 500 0.0
# 501 0.0
# 502 0.0
# 503 0.0
# 504 0.0
# 505 0.0
# 506 0.0
# 507 0.0
# 508 0.0
# 509 0.0
# 510 0.0
# 511 0.0
# 512 0.0
# 513 0.0
# 514 0.0
# 515 0.0
# 516 0.0
# 517 0.0
# 518 0.0
# 519 0.0
# 520 0.0
# 521 0.0
# 522 0.0
# 523 0.0
# 524 0.0
# 525 0.0
# 526 0.0
# 527 0.0
# 528 0.0
# 529 0.0
# 530 0.0
# 531 0.0
# 532 0.0
# 533 0.0
# 534 0.0
# 535 0.0
# 536 0.0
# 537 0.0
# 538 0.0
# 539 0.0
# 540 0.0
# 541 0.0
# 542 0.0
# 543 0.0
# 544 0.0
# 545 0.0
# 546 0.0
# 547 0.0
# 548 0.0
# 549 0.0
# 550 0.0
# 551 0.0
# 552 0.0
# 553 0.0
# 554 0.0
# 555 0.0
# 556 0.0
# 557 0.0
# 558 0.0
# 559 0.0
# 560 0.0
# 561 0.0
# 562 0.0
# 563 0.0
# 564 0.0
# 565 0.0
# 566 0.0
# 567 0.0
# 568 0.0
# 569 0.0
# 570 0.0
# 571 0.0
# 572 0.0
# 573 0.0
# 574 0.0
# 575 0.0
# 576 0.0
# 577 0.0
# 578 0.0
# 579 0.0
# 580 0.0
# 581 0.0
# 582 0.0
# 583 0.0
# 584 0.0
# 585 0.0
# 586 0.0
# 587 0.0
# 588 0.0
# 589 0.0
# 590 0.0
# 591 0.0
# 592 0.0
# 593 0.0
# 594 0.0
# 595 0.0
# 596 0.0
# 597 0.0
# 598 0.0
# 599 0.0
# 600 0.0
# 601 0.0
# 602 0.0
# 603 0.0
# 604 0.0
# 605 0.0
# 606 0.0
# 607 0.0
# 608 0.0
# 609 0.0
# 610 0.0
# 611 0.0
# 612 0.0
# 613 0.0
# 614 0.0
# 615 0.0
# 616 0.0
# 617 0.0
# 618 0.0
# 619 0.0
# 620 0.0
# 621 0.0
# 622 0.0
# 623 0.0
# 624 0.0
# 625 0.0
# 626 0.0
# 627 0.0
# 628 0.0
# 629 0.0
# 630 0.0
# 631 0.0
# 632 0.0
# 633 0.0
# 634 0.0
# 635 0.0
# 636 0.0
# 637 0.0
# 638 0.0
# 639 0.0
# 640 0.0
# 641 0.0
# 642 0.0
# 643 0.0
# 644 0.0
# 645 0.0
# 646 0.0
# 647 0.0
# 648 0.0
# 649 0.0
# 650 0.0
# 651 0.0
# 652 0.0
# 653 0.0
# 654 0.0
# 655 0.0
# 656 0.0
# 657 0.0
# 658 0.0
# 659 0.0
# 660 0.0
# 661 0.0
# 662 0.0
# 663 0.0
# 664 0.0
# 665 0.0
# 666 0.0
# 667 0.0
# 668 0.0
# 669 0.0
# 670 0.0
# 671 0.0
# 672 0.0
# 673 0.0
# 674 0.0
# 675 0.0
# 676 0.0
# 677 0.0
# 678 0.0
# 679 0.0
# 680 0.0
# 681 0.0
# 682 0.0
# 683 0.0
# 684 0.0
# 685 0.0
# 686 0.0
# 687 0.0
# 688 0.0
# 689 0.0
# 690 0.0
# 691 0.0
# 692 0.0
# 693 0.0
# 694 0.0
# 695 0.0
# 696 0.0
# 697 0.0
# 698 0.0
# 699 0.0
# 700 0.0
# 701 0.0
# 702 0.0
# 703 0.0
# 704 0.0
# 705 0.0
# 706 0.0
# 707 0.0
# 708 0.0
# 709 0.0
# 710 0.0
# 711 0.0
# 712 0.0
# 713 0.0
# 714 0.0
# 715 0.0
# 716 0.0
# 717 0.0
# 718 0.0
# 719 0.0
# 720 0.0
# 721 0.0
# 722 0.0
# 723 0.0
# 724 0.0
# 725 0.0
# 726 0.0
# 727 0.0
# 728 0.0
# 729 0.0
# 730 0.0
# 731 0.0
# 732 0.0
# 733 0.0
# 734 0.0
# 735 0.0
# 736 0.0
# 737 0.0
# 738 0.0
# 739 0.0
# 740 0.0
# 741 0.0
# 742 0.0
# 743 0.0
# 744 0.0
# 745 0.0
# 746 0.0
# 747 0.0
# 748 0.0
# 749 0.0
# 750 0.0
# 751 0.0
# 752 0.0
# 753 0.0
# 754 0.0
# 755 0.0
# 756 0.0
# 757 0.0
# 758 0.0
# 759 0.0
# 760 0.0
# 761 0.0
# 762 0.0
# 763 0.0
# 764 0.0
# 765 0.0
# 766 0.0
# 767 0.0
# 768 0.0
# 769 0.0
# 770 0.0
# 771 0.0
# 772 0.0
# 773 0.0
# 774 0.0
# 775 0.0
# 776 0.0
# 777 0.0
# 778 0.0
# 779 0.0
# 780 0.0
# 781 0.0
# 782 0.0
# 783 0.0
# 784 0.0
# 785 0.0
# 786 0.0
# 787 0.0
# 788 0.0
# 789 0.0
# 790 0.0
# 791 0.0
# 792 0.0
# 793 0.0
# 794 0.0
# 795 0.0
# 796 0.0
# 797 0.0
# 798 0.0
# 799 0.0
# 800 0.0
# 801 0.0
# 802 0.0
# 803 0.0
# 804 0.0
# 805 0.0
# 806 0.0
# 807 0.0
# 808 0.0
# 809 0.0
# 810 0.0
# 811 0.0
# 812 0.0
# 813 0.0
# 814 0.0
# 815 0.0
# 816 0.0
# 817 0.0
# 818 0.0
# 819 0.0
# 820 0.0
# 821 0.0
# 822 0.0
# 823 0.0
# 824 0.0
# 825 0.0
# 826 0.0
# 827 0.0
# 828 0.0
# 829 0.0
# 830 0.0
# 831 0.0
# 832 0.0
# 833 0.0
# 834 0.0
# 835 0.0
# 836 0.0
# 837 0.0
# 838 0.0
# 839 0.0
# 840 0.0
# 841 0.0
# 842 0.0
# 843 0.0
# 844 0.0
# 845 0.0
# 846 0.0
# 847 0.0
# 848 0.0
# 849 0.0
# 850 0.0
# 851 0.0
# 852 0.0
# 853 0.0
# 854 0.0
# 855 0.0
# 856 0.0
# 857 0.0
# 858 0.0
# 859 0.0
# 860 0.0
# 861 0.0
# 862 0.0
# 863 0.0
# 864 0.0
# 865 0.0
# 866 0.0
# 867 0.0
# 868 0.0
# 869 0.0
# 870 0.0
# 871 0.0
# 872 0.0
# 873 0.0
# 874 0.0
# 875 0.0
# 876 0.0
# 877 0.0
# 878 0.0
# 879 0.0
# 880 0.0
# 881 0.0
# 882 0.0
# 883 0.0
# 884 0.0
# 885 0.0
# 886 0.0
# 887 0.0
# 888 0.0
# 889 0.0
# 890 0.0
# 891 0.0
# 892 0.0
# 893 0.0
# 894 0.0
# 895 0.0
# 896 0.0
# 897 0.0
# 898 0.0
# 899 0.0
# 900 0.0
# 901 0.0
# 902 0.0
# 903 0.0
# 904 0.0
# 905 0.0
# 906 0.0
# 907 0.0
# 908 0.0
# 909 0.0
# 910 0.0
# 911 0.0
# 912 0.0
# 913 0.0
# 914 0.0
# 915 0.0
# 916 0.0
# 917 0.0
# 918 0.0
# 919 0.0
# 920 0.0
# 921 0.0
# 922 0.0
# 923 0.0
# 924 0.0
# 925 0.0
# 926 0.0
# 927 0.0
# 928 0.0
# 929 0.0
# 930 0.0
# 931 0.0
# 932 0.0
# 933 0.0
# 934 0.0
# 935 0.0
# 936 0.0
# 937 0.0
# 938 0.0
# 939 0.0
# 940 0.0
# 941 0.0
# 942 0.0
# 943 0.0
# 944 0.0
# 945 0.0
# 946 0.0
# 947 0.0
# 948 0.0
# 949 0.0
# 950 0.0
# 951 0.0
# 952 0.0
# 953 0.0
# 954 0.0
# 955 0.0
# 956 0.0
# 957 0.0
# 958 0.0
# 959 0.0
# 960 0.0
# 961 0.0
# 962 0.0
# 963 0.0
# 964 0.0
# 965 0.0
# 966 0.0
# 967 0.0
# 968 0.0
# 969 0.0
# 970 0.0
# 971 0.0
# 972 0.0
# 973 0.0
# 974 0.0
# 975 0.0
# 976 0.0
# 977 0.0
# 978 0.0
# 979 0.0
# 980 0.0
# 981 0.0
# 982 0.0
# 983 0.0
# 984 0.0
# 985 0.0
# 986 0.0
# 987 0.0
# 988 0.0
# 989 0.0
# 990 0.0
# 991 0.0
# 992 0.0
# 993 0.0
# 994 0.0
# 995 0.0
# 996 0.0
# 997 0.0
# 998 0.0
# 999 0.0
# 1000 0.0
# 1001 0.0
# 1002 0.0
# 1003 0.0
# 1004 0.0
# 1005 0.0
# 1006 0.0
# 1007 0.0
# 1008 0.0
# 1009 0.0
# 1010 0.0
# 1011 0.0
# 1012 0.0
# 1013 0.0
# 1014 0.0
# 1015 0.0
# 1016 0.0
# 1017 0.0
# 1018 0.0
# 1019 0.0
# 1020 0.0
# 1021 0.0
# 1022 0.0
# 1023 0.0
# 1024 0.0
# 1025 0.0
# 1026 0.0
# 1027 0.0
# 1028 0.0
# 1029 0.0
# 1030 0.0
# 1031 0.0
# 1032 0.0
# 1033 0.0
# 1034 0.0
# 1035 0.0
# 1036 0.0
# 1037 0.0
# 1038 0.0
# 1039 0.0
# 1040 0.0
# 1041 0.0
# 1042 0.0
# 1043 0.0
# 1044 0.0
# 1045 0.0
# 1046 0.0
# 1047 0.0
# 1048 0.0
# 1049 0.0
# 1050 0.0
# 1051 0.0
# 1052 0.0
# 1053 0.0
# 1054 0.0
# 1055 0.0
# 1056 0.0
# 1057 0.0
# 1058 0.0
# 1059 0.0
# 1060 0.0
# 1061 0.0
# 1062 0.0
# 1063 0.0
# 1064 0.0
# 1065 0.0
# 1066 0.0
# 1067 0.0
# 1068 0.0
# 1069 0.0
# 1070 0.0
# 1071 0.0
# 1072 0.0
# 1073 0.0
# 1074 0.0
# 1075 0.0
# 1076 0.0
# 1077 0.0
# 1078 0.0
# 1079 0.0
# 1080 0.0
# 1081 0.0
# 1082 0.0
# 1083 0.0
# 1084 0.0
# 1085 0.0
# 1086 0.0
# 1087 0.0
# 1088 0.0
# 1089 0.0
# 1090 0.0
# 1091 0.0
# 1092 0.0
# 1093 0.0
# 1094 0.0
# 1095 0.0
# 1096 0.0
# 1097 0.0
# 1098 0.0
# 1099 0.0
# 1100 0.0
# 1101 0.0
# 1102 0.0
# 1103 0.0
# 1104 0.0
# 1105 0.0
# 1106 0.0
# 1107 0.0
# 1108 0.0
# 1109 0.0
# 1110 0.0
# 1111 0.0
# 1112 0.0
# 1113 0.0
# 1114 0.0
# 1115 0.0
# 1116 0.0
# 1117 0.0
# 1118 0.0
# 1119 0.0
# 1120 0.0
# 1121 0.0
# 1122 0.0
# 1123 0.0
# 1124 0.0
# 1125 0.0
# 1126 0.0
# 1127 0.0
# 1128 0.0
# 1129 0.0
# 1130 0.0
# 1131 0.0
# 1132 0.0
# 1133 0.0
# 1134 0.0
# 1135 0.0
# 1136 0.0
# 1137 0.0
# 1138 0.0
# 1139 0.0
# 1140 0.0
# 1141 0.0
# 1142 0.0
# 1143 0.0
# 1144 0.0
# 1145 0.0
# 1146 0.0
# 1147 0.0
# 1148 0.0
# 1149 0.0
# 1150 0.0
# 1151 0.0
# 1152 0.0
# 1153 0.0
# 1154 0.0
# 1155 0.0
# 1156 0.0
# 1157 0.0
# 1158 0.0
# 1159 0.0
# 1160 0.0
# 1161 0.0
# 1162 0.0
# 1163 0.0
# 1164 0.0
# 1165 0.0
# 1166 0.0
# 1167 0.0
# 1168 0.0
# 1169 0.0
# 1170 0.0
# 1171 0.0
# 1172 0.0
# 1173 0.0
# 1174 0.0
# 1175 0.0
# 1176 0.0
# 1177 0.0
# 1178 0.0
# 1179 0.0
# 1180 0.0
# 1181 0.0
# 1182 0.0
# 1183 0.0
# 1184 0.0
# 1185 0.0
# 1186 0.0
# 1187 0.0
# 1188 0.0
# 1189 0.0
# 1190 0.0
# 1191 0.0
# 1192 0.0
# 1193 0.0
# 1194 0.0
# 1195 0.0
# 1196 0.0
# 1197 0.0
# 1198 0.0
# 1199 0.0
# 1200 0.0
# 1201 0.0
# 1202 0.0
# 1203 0.0
# 1204 0.0
# 1205 0.0
# 1206 0.0
# 1207 0.0
# 1208 0.0
# 1209 0.0
# 1210 0.0
# 1211 0.0
# 1212 0.0
# 1213 0.0
# 1214 0.0
# 1215 0.0
# 1216 0.0
# 1217 0.0
# 1218 0.0
# 1219 0.0
# 1220 0.0
# 1221 0.0
# 1222 0.0
# 1223 0.0
# 1224 0.0
# 1225 0.0
# 1226 0.0
# 1227 0.0
# 1228 0.0
# 1229 0.0
# 1230 0.0
# 1231 0.0
# 1232 0.0
# 1233 0.0
# 1234 0.0
# 1235 0.0
# 1236 0.0
# 1237 0.0
# 1238 0.0
# 1239 0.0
# 1240 0.0
# 1241 0.0
# 1242 0.0
# 1243 0.0
# 1244 0.0
# 1245 0.0
# 1246 0.0
# 1247 0.0
# 1248 0.0
# 1249 0.0
# 1250 0.0
# 1251 0.0
# 1252 0.0
# 1253 0.0
# 1254 0.0
# 1255 0.0
# 1256 0.0
# 1257 0.0
# 1258 0.0
# 1259 0.0
# 1260 0.0
# 1261 0.0
# 1262 0.0
# 1263 0.0
# 1264 0.0
# 1265 0.0
# 1266 0.0
# 1267 0.0
# 1268 0.0
# 1269 0.0
# 1270 0.0
# 1271 0.0
# 1272 0.0
# 1273 0.0
# 1274 0.0
# 1275 0.0
# 1276 0.0
# 1277 0.0
# 1278 0.0
# 1279 0.0
# 1280 0.0
# 1281 0.0
# 1282 0.0
# 1283 0.0
# 1284 0.0
# 1285 0.0
# 1286 0.0
# 1287 0.0
# 1288 0.0
# 1289 0.0
# 1290 0.0
# 1291 0.0
# 1292 0.0
# 1293 0.0
# 1294 0.0
# 1295 0.0
# 1296 0.0
# 1297 0.0
# 1298 0.0
# 1299 0.0
# 1300 0.0
# 1301 0.0
# 1302 0.0
# 1303 0.0
# 1304 0.0
# 1305 0.0
# 1306 0.0
# 1307 0.0
# 1308 0.0
# 1309 0.0
# 1310 0.0
# 1311 0.0
# 1312 0.0
# 1313 0.0
# 1314 0.0
# 1315 0.0
# 1316 0.0
# 1317 0.0
# 1318 0.0
# 1319 0.0
# 1320 0.0
# 1321 0.0
# 1322 0.0
# 1323 0.0
# 1324 0.0
# 1325 0.0
# 1326 0.0
# 1327 0.0
# 1328 0.0
# 1329 0.0
# 1330 0.0
# 1331 0.0
# 1332 0.0
# 1333 0.0
# 1334 0.0
# 1335 0.0
# 1336 0.0
# 1337 0.0
# 1338 0.0
# 1339 0.0
# 1340 0.0
# 1341 0.0
# 1342 0.0
# 1343 0.0
# 1344 0.0
# 1345 0.0
# 1346 0.0
# 1347 0.0
# 1348 0.0
# 1349 0.0
# 1350 0.0
# 1351 0.0
# 1352 0.0
# 1353 0.0
# 1354 0.0
# 1355 0.0
# 1356 0.0
# 1357 0.0
# 1358 0.0
# 1359 0.0
# 1360 0.0
# 1361 0.0
# 1362 0.0
# 1363 0.0
# 1364 0.0
# 1365 0.0
# 1366 0.0
# 1367 0.0
# 1368 0.0
# 1369 0.0
# 1370 0.0
# 1371 0.0
# 1372 0.0
# 1373 0.0
# 1374 0.0
# 1375 0.0
# 1376 0.0
# 1377 0.0
# 1378 0.0
# 1379 0.0
# 1380 0.0
# 1381 0.0
# 1382 0.0
# 1383 0.0
# 1384 0.0
# 1385 0.0
# 1386 0.0
# 1387 0.0
# 1388 0.0
# 1389 0.0
# 1390 0.0
# 1391 0.0
# 1392 0.0
# 1393 0.0
# 1394 0.0
# 1395 0.0
# 1396 0.0
# 1397 0.0
# 1398 0.0
# 1399 0.0
# 1400 0.0
# 1401 0.0
# 1402 0.0
# 1403 0.0
# 1404 0.0
# 1405 0.0
# 1406 0.0
# 1407 0.0
# 1408 0.0
# 1409 0.0
# 1410 0.0
# 1411 0.0
# 1412 0.0
# 1413 0.0
# 1414 0.0
# 1415 0.0
# 1416 0.0
# 1417 0.0
# 1418 0.0
# 1419 0.0
# 1420 0.0
# 1421 0.0
# 1422 0.0
# 1423 0.0
# 1424 0.0
# 1425 0.0
# 1426 0.0
# 1427 0.0
# 1428 0.0
# 1429 0.0
# 1430 0.0
# 1431 0.0
# 1432 0.0
# 1433 0.0
# 1434 0.0
# 1435 0.0
# 1436 0.0
# 1437 0.0
# 1438 0.0
# 1439 0.0
# 1440 0.0
# 1441 0.0
# 1442 0.0
# 1443 0.0
# 1444 0.0
# 1445 0.0
# 1446 0.0
# 1447 0.0
# 1448 0.0
# 1449 0.0
# 1450 0.0
# 1451 0.0
# 1452 0.0
# 1453 0.0
# 1454 0.0
# 1455 0.0
# 1456 0.0
# 1457 0.0
# 1458 0.0
# 1459 0.0
# 1460 0.0
# 1461 0.0
# 1462 0.0
# 1463 0.0
# 1464 0.0
# 1465 0.0
# 1466 0.0
# 1467 0.0
# 1468 0.0
# 1469 0.0
# 1470 0.0
# 1471 0.0
# 1472 0.0
# 1473 0.0
# 1474 0.0
# 1475 0.0
# 1476 0.0
# 1477 0.0
# 1478 0.0
# 1479 0.0
# 1480 0.0
# 1481 0.0
# 1482 0.0
# 1483 0.0
# 1484 0.0
# 1485 0.0
# 1486 0.0
# 1487 0.0
# 1488 0.0
# 1489 0.0
# 1490 0.0
# 1491 0.0
# 1492 0.0
# 1493 0.0
# 1494 0.0
# 1495 0.0
# 1496 0.0
# 1497 0.0
# 1498 0.0
# 1499 0.0
# 1500 0.0
# 1501 0.0
# 1502 0.0
# 1503 0.0
# 1504 0.0
# 1505 0.0
# 1506 0.0
# 1507 0.0
# 1508 0.0
# 1509 0.0
# 1510 0.0
# 1511 0.0
# 1512 0.0
# 1513 0.0
# 1514 0.0
# 1515 0.0
# 1516 0.0
# 1517 0.0
# 1518 0.0
# 1519 0.0
# 1520 0.0
# 1521 0.0
# 1522 0.0
# 1523 0.0
# 1524 0.0
# 1525 0.0
# 1526 0.0
# 1527 0.0
# 1528 0.0
# 1529 0.0
# 1530 0.0
# 1531 0.0
# 1532 0.0
# 1533 0.0
# 1534 0.0
# 1535 0.0
# 1536 0.0
# 1537 0.0
# 1538 0.0
# 1539 0.0
# 1540 0.0
# 1541 0.0
# 1542 0.0
# 1543 0.0
# 1544 0.0
# 1545 0.0
# 1546 0.0
# 1547 0.0
# 1548 0.0
# 1549 0.0
# 1550 0.0
# 1551 0.0
# 1552 0.0
# 1553 0.0
# 1554 0.0
# 1555 0.0
# 1556 0.0
# 1557 0.0
# 1558 0.0
# 1559 0.0
# 1560 0.0
# 1561 0.0
# 1562 0.0
# 1563 0.0
# 1564 0.0
# 1565 0.0
# 1566 0.0
# 1567 0.0
# 1568 0.0
# 1569 0.0
# 1570 0.0
# 1571 0.0
# 1572 0.0
# 1573 0.0
# 1574 0.0
# 1575 0.0
# 1576 0.0
# 1577 0.0
# 1578 0.0
# 1579 0.0
# 1580 0.0
# 1581 0.0
# 1582 0.0
# 1583 0.0
# 1584 0.0
# 1585 0.0
# 1586 0.0
# 1587 0.0
# 1588 0.0
# 1589 0.0
# 1590 0.0
# 1591 0.0
# 1592 0.0
# 1593 0.0
# 1594 0.0
# 1595 0.0
# 1596 0.0
# 1597 0.0
# 1598 0.0
# 1599 0.0
# 1600 0.0
# 1601 0.0
# 1602 0.0
# 1603 0.0
# 1604 0.0
# 1605 0.0
# 1606 0.0
# 1607 0.0
# 1608 0.0
# 1609 0.0
# 1610 0.0
# 1611 0.0
# 1612 0.0
# 1613 0.0
# 1614 0.0
# 1615 0.0
# 1616 0.0
# 1617 0.0
# 1618 0.0
# 1619 0.0
# 1620 0.0
# 1621 0.0
# 1622 0.0
# 1623 0.0
# 1624 0.0
# 1625 0.0
# 1626 0.0
# 1627 0.0
# 1628 0.0
# 1629 0.0
# 1630 0.0
# 1631 0.0
# 1632 0.0
# 1633 0.0
# 1634 0.0
# 1635 0.0
# 1636 0.0
# 1637 0.0
# 1638 0.0
# 1639 0.0
# 1640 0.0
# 1641 0.0
# 1642 0.0
# 1643 0.0
# 1644 0.0
# 1645 0.0
# 1646 0.0
# 1647 0.0
# 1648 0.0
# 1649 0.0
# 1650 0.0
# 1651 0.0
# 1652 0.0
# 1653 0.0
# 1654 0.0
# 1655 0.0
# 1656 0.0
# 1657 0.0
# 1658 0.0
# 1659 0.0
# 1660 0.0
# 1661 0.0
# 1662 0.0
# 1663 0.0
# 1664 0.0
# 1665 0.0
# 1666 0.0
# 1667 0.0
# 1668 0.0
# 1669 0.0
# 1670 0.0
# 1671 0.0
# 1672 0.0
# 1673 0.0
# 1674 0.0
# 1675 0.0
# 1676 0.0
# 1677 0.0
# 1678 0.0
# 1679 0.0
# 1680 0.0
# 1681 0.0
# 1682 0.0
# 1683 0.0
# 1684 0.0
# 1685 0.0
# 1686 0.0
# 1687 0.0
# 1688 0.0
# 1689 0.0
# 1690 0.0
# 1691 0.0
# 1692 0.0
# 1693 0.0
# 1694 0.0
# 1695 0.0
# 1696 0.0
# 1697 0.0
# 1698 0.0
# 1699 0.0
# 1700 0.0
# 1701 0.0
# 1702 0.0
# 1703 0.0
# 1704 0.0
# 1705 0.0
# 1706 0.0
# 1707 0.0
# 1708 0.0
# 1709 0.0
# 1710 0.0
# 1711 0.0
# 1712 0.0
# 1713 0.0
# 1714 0.0
# 1715 0.0
# 1716 0.0
# 1717 0.0
# 1718 0.0
# 1719 0.0
# 1720 0.0
# 1721 0.0
# 1722 0.0
# 1723 0.0
# 1724 0.0
# 1725 0.0
# 1726 0.0
# 1727 0.0
# 1728 0.0
# 1729 0.0
# 1730 0.0
# 1731 0.0
# 1732 0.0
# 1733 0.0
# 1734 0.0
# 1735 0.0
# 1736 0.0
# 1737 0.0
# 1738 0.0
# 1739 0.0
# 1740 0.0
# 1741 0.0
# 1742 0.0
# 1743 0.0
# 1744 0.0
# 1745 0.0
# 1746 0.0
# 1747 0.0
# 1748 0.0
# 1749 0.0
# 1750 0.0
# 1751 0.0
# 1752 0.0
# 1753 0.0
# 1754 0.0
# 1755 0.0
# 1756 0.0
# 1757 0.0
# 1758 0.0
# 1759 0.0
# 1760 0.0
# 1761 0.0
# 1762 0.0
# 1763 0.0
# 1764 0.0
# 1765 0.0
# 1766 0.0
# 1767 0.0
# 1768 0.0
# 1769 0.0
# 1770 0.0
# 1771 0.0
# 1772 0.0
# 1773 0.0
# 1774 0.0
# 1775 0.0
# 1776 0.0
# 1777 0.0
# 1778 0.0
# 1779 0.0
# 1780 0.0
# 1781 0.0
# 1782 0.0
# 1783 0.0
# 1784 0.0
# 1785 0.0
# 1786 0.0
# 1787 0.0
# 1788 0.0
# 1789 0.0
# 1790 0.0
# 1791 0.0
# 1792 0.0
# 1793 0.0
# 1794 0.0
# 1795 0.0
# 1796 0.0
# 1797 0.0
# 1798 0.0
# 1799 0.0
# 1800 0.0
# 1801 0.0
# 1802 0.0
# 1803 0.0
# 1804 0.0
# 1805 0.0
# 1806 0.0
# 1807 0.0
# 1808 0.0
# 1809 0.0
# 1810 0.0
# 1811 0.0
# 1812 0.0
# 1813 0.0
# 1814 0.0
# 1815 0.0
# 1816 0.0
# 1817 0.0
# 1818 0.0
# 1819 0.0
# 1820 0.0
# 1821 0.0
# 1822 0.0
# 1823 0.0
# 1824 0.0
# 1825 0.0
# 1826 0.0
# 1827 0.0
# 1828 0.0
# 1829 0.0
# 1830 0.0
# 1831 0.0
# 1832 0.0
# 1833 0.0
# 1834 0.0
# 1835 0.0
# 1836 0.0
# 1837 0.0
# 1838 0.0
# 1839 0.0
# 1840 0.0
# 1841 0.0
# 1842 0.0
# 1843 0.0
# 1844 0.0
# 1845 0.0
# 1846 0.0
# 1847 0.0
# 1848 0.0
# 1849 0.0
# 1850 0.0
# 1851 0.0
# 1852 0.0
# 1853 0.0
# 1854 0.0
# 1855 0.0
# 1856 0.0
# 1857 0.0
# 1858 0.0
# 1859 0.0
# 1860 0.0
# 1861 0.0
# 1862 0.0
# 1863 0.0
# 1864 0.0
# 1865 0.0
# 1866 0.0
# 1867 0.0
# 1868 0.0
# 1869 0.0
# 1870 0.0
# 1871 0.0
# 1872 0.0
# 1873 0.0
# 1874 0.0
# 1875 0.0
# 1876 0.0
# 1877 0.0
# 1878 0.0
# 1879 0.0
# 1880 0.0
# 1881 0.0
# 1882 0.0
# 1883 0.0
# 1884 0.0
# 1885 0.0
# 1886 0.0
# 1887 0.0
# 1888 0.0
# 1889 0.0
# 1890 0.0
# 1891 0.0
# 1892 0.0
# 1893 0.0
# 1894 0.0
# 1895 0.0
# 1896 0.0
# 1897 0.0
# 1898 0.0
# 1899 0.0
# 1900 0.0
# 1901 0.0
# 1902 0.0
# 1903 0.0
# 1904 0.0
# 1905 0.0
# 1906 0.0
# 1907 0.0
# 1908 0.0
# 1909 0.0
# 1910 0.0
# 1911 0.0
# 1912 0.0
# 1913 0.0
# 1914 0.0
# 1915 0.0
# 1916 0.0
# 1917 0.0
# 1918 0.0
# 1919 0.0
# 1920 0.0
# 1921 0.0
# 1922 0.0
# 1923 0.0
# 1924 0.0
# 1925 0.0
# 1926 0.0
# 1927 0.0
# 1928 0.0
# 1929 0.0
# 1930 0.0
# 1931 0.0
# 1932 0.0
# 1933 0.0
# 1934 0.0
# 1935 0.0
# 1936 0.0
# 1937 0.0
# 1938 0.0
# 1939 0.0
# 1940 0.0
# 1941 0.0
# 1942 0.0
# 1943 0.0
# 1944 0.0
# 1945 0.0
# 1946 0.0
# 1947 0.0
# 1948 0.0
# 1949 0.0
# 1950 0.0
# 1951 0.0
# 1952 0.0
# 1953 0.0
# 1954 0.0
# 1955 0.0
# 1956 0.0
# 1957 0.0
# 1958 0.0
# 1959 0.0
# 1960 0.0
# 1961 0.0
# 1962 0.0
# 1963 0.0
# 1964 0.0
# 1965 0.0
# 1966 0.0
# 1967 0.0
# 1968 0.0
# 1969 0.0
# 1970 0.0
# 1971 0.0
# 1972 0.0
# 1973 0.0
# 1974 0.0
# 1975 0.0
# 1976 0.0
# 1977 0.0
# 1978 0.0
# 1979 0.0
# 1980 0.0
# 1981 0.0
# 1982 0.0
# 1983 0.0
# 1984 0.0
# 1985 0.0
# 1986 0.0
# 1987 0.0
# 1988 0.0
# 1989 0.0
# 1990 0.0
# 1991 0.0
# 1992 0.0
# 1993 0.0
# 1994 0.0
# 1995 0.0
# 1996 0.0
# 1997 0.0
# 1998 0.0

# %%
plt.xticks(np.arange(min(currentDay), max(currentDay)+1, 1.0))
plt.bar(currentDay,newInfected, color="green",width=0.7)
#print(currentDay)
#plt.savefig("obedient200stous500v2.jpg")
# Out:
# <BarContainer object of 39 artists>

# %%
import imageio
images=[]
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave('people_move_movie.gif', images,duration=0.5)
images=[]
for filename in filenames2:
    images.append(imageio.imread(filename))
imageio.mimsave('cases.gif', images,duration=0.5)

# %%
for i in range(0,len(people)):
    relationshipFile2.write(str(i))
    for j in Grelationship.neighbors(i):
        relationshipFile2.write(',')
        relationshipFile2.write(str(j))
    relationshipFile2.write('\n')

relationshipFile2.close()

# %%
plt.xticks(np.arange(min(list1), max(list1)+1, 1.0))
plt.plot(list1,list2, color='blue', linewidth=3)
plt.show()
